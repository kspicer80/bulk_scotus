# %%
import re
import string
import numpy as np
import pandas as pd
from tqdm.auto import tqdm
import nltk
from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk import word_tokenize

import matplotlib.pyplot as plt
import plotly.express as px
from plotly.graph_objs import *

import seaborn as sns

# %%
df = pd.read_csv('/Users/spicy.kev/Documents/github/ussc_text_classification/cleaned_text_file.csv')
df.head(10)
# Out:
#    date_filed plain_text                                               html  \
# 0  1773-09-01        NaN  <p class="case_cite">1 U.S. 20</p>\r\n    <p c...
# 1  1773-04-01        NaN  <p class="case_cite">1 U.S. 18</p>\r\n    <p c...
# 2  1787-06-01        NaN  <p class="case_cite">1 U.S. 194</p>\n    <p cl...
# 3  1787-09-01        NaN  <p class="case_cite">1 U.S. 210</p>\r\n    <p ...
# 4  1787-04-01        NaN  <p class="case_cite">2 U.S. 97</p>\n    <p cla...
# 5  1780-04-01        NaN  <p class="case_cite">1 U.S. 47</p>\n    <p cla...
# 6  1780-04-01        NaN  <p class="case_cite">1 U.S. 49</p>\r\n    <p c...
# 7  1789-09-01        NaN  <p class="case_cite">1 U.S. 441</p>\n    <p cl...
# 8  1789-01-01        NaN  <p class="case_cite">1 U.S. 406</p>\n    <p cl...
# 9  1789-12-01        NaN  <p class="case_cite">1 U.S. 480</p>\n    <p cl...
#
#                                  html_with_citations  label  \
# 0  <p class="case_cite"><span class="citation no-...   1700
# 1  <p class="case_cite"><span class="citation no-...   1700
# 2  <div>\n<center><b><span class="citation no-lin...   1700
# 3  <div>\n<center><b><span class="citation no-lin...   1700
# 4  <p class="case_cite"><span class="citation no-...   1700
# 5  <p class="case_cite"><span class="citation no-...   1700
# 6  <div>\n<center><b><span class="citation no-lin...   1700
# 7  <p class="case_cite"><span class="citation no-...   1700
# 8  <p class="case_cite"><span class="citation no-...   1700
# 9  <div>\n<center><b><span class="citation no-lin...   1700
#
#                                         cleaned_text
# 0  1 U.S. 20 1 Dall. 20 1 L.Ed. 19 ANONYMOUS. No....
# 1  1 U.S. 18 1 Dall. 18 1 L.Ed. 18 The Lessee of ...
# 2   1 U.S. 194 (1787) 1 Dall. 194 GERARD versus L...
# 3   1 U.S. 210 (1787) 1 Dall. 210 POLLARD versus ...
# 4  2 U.S. 97 2 Dall. 97 1 L.Ed. 305 Pringlev.Blac...
# 5  1 U.S. 47 1 Dall. 47 1 L.Ed. 31 JAMES'S CLAIM....
# 6   1 U.S. 49 (1780) 1 Dall. 49 MONTGOMERY versus...
# 7  1 U.S. 441 1 Dall. 441 1 L.Ed. 214 M'Cullough,...
# 8  1 U.S. 406 1 Dall. 406 1 L.Ed. 197 Johnsonv.Ho...
# 9   1 U.S. 480 (1789) 1 Dall. 480 LYLE, Admor. ve...

# %%
# Some Standard Text Cleaning Functions

def convert_to_lower(text):
    return text.lower()

def remove_numbers(text):
    number_pattern = r'\d+'
    without_number = re.sub(pattern=number_pattern, repl=" ", string=text)
    return without_number

def remove_punctuation(text):
    return text.translate(str.maketrans('', '', string.punctuation))

def remove_stopwords(text):
    removed = []
    stop_words = list(stopwords.words("english"))
    tokens = word_tokenize(text)
    for i in range(len(tokens)):
        if tokens[i] not in stop_words:
            removed.append(tokens[i])
    return " ".join(removed)

# %%
from tqdm._tqdm_notebook import tqdm_notebook
tqdm_notebook.pandas()
# Out:
# /var/folders/0h/96f5xt0s59j0cyt_3yf1j_0w0000gn/T/ipykernel_23605/1383614074.py:1: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.*` instead of `tqdm._tqdm_notebook.*`
#   from tqdm._tqdm_notebook import tqdm_notebook

# %%
df['cleaned_text'] = df['cleaned_text'].progress_apply(lambda x: convert_to_lower(x))
df['cleaned_text'] = df['cleaned_text'].progress_apply(lambda x: remove_numbers(x))
df['cleaned_text'] = df['cleaned_text'].progress_apply(lambda x: remove_punctuation(x))
df['cleaned_text'] = df['cleaned_text'].progress_apply(lambda x: remove_stopwords(x))
# Out:
#   0%|          | 0/61314 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/spicy.kev/Documents/github/ussc_text_classification/text_cleaning_and_eda.ipynb Cell 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/spicy.kev/Documents/github/ussc_text_classification/text_cleaning_and_eda.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> df['cleaned_text'] = df['cleaned_text'].progress_apply(lambda x: convert_to_lower(x))
#       <a href='vscode-notebook-cell:/Users/spicy.kev/Documents/github/ussc_text_classification/text_cleaning_and_eda.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> df['cleaned_text'] = df['cleaned_text'].progress_apply(lambda x: remove_numbers(x))
#       <a href='vscode-notebook-cell:/Users/spicy.kev/Documents/github/ussc_text_classification/text_cleaning_and_eda.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> df['cleaned_text'] = df['cleaned_text'].progress_apply(lambda x: remove_punctuation(x))
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tqdm/std.py:814, in tqdm.pandas.<locals>.inner_generator.<locals>.inner(df, func, *args, **kwargs)
#     811 # Apply the provided function (in **kwargs)
#     812 # on the df using our wrapper (which provides bar updating)
#     813 try:
# --> 814     return getattr(df, df_function)(wrapper, **kwargs)
#     815 finally:
#     816     t.close()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py:1137, in SeriesApply.apply_standard(self)
#    1131         values = obj.astype(object)._values
#    1132         # error: Argument 2 to "map_infer" has incompatible type
#    1133         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1134         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1135         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136         # "Callable[[Any], Any]"
# -> 1137         mapped = lib.map_infer(
#    1138             values,
#    1139             f,  # type: ignore[arg-type]
#    1140             convert=self.convert_dtype,
#    1141         )
#    1143 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1144     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1145     #  See also GH#25959 regarding EA support
#    1146     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tqdm/std.py:809, in tqdm.pandas.<locals>.inner_generator.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     803 def wrapper(*args, **kwargs):
#     804     # update tbar correctly
#     805     # it seems `pandas apply` calls `func` twice
#     806     # on the first column/row to decide whether it can
#     807     # take a fast or slow code path; so stop when t.total==t.n
#     808     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 809     return func(*args, **kwargs)
#
# /Users/spicy.kev/Documents/github/ussc_text_classification/text_cleaning_and_eda.ipynb Cell 5 in <lambda>(x)
# ----> <a href='vscode-notebook-cell:/Users/spicy.kev/Documents/github/ussc_text_classification/text_cleaning_and_eda.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> df['cleaned_text'] = df['cleaned_text'].progress_apply(lambda x: convert_to_lower(x))
#       <a href='vscode-notebook-cell:/Users/spicy.kev/Documents/github/ussc_text_classification/text_cleaning_and_eda.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> df['cleaned_text'] = df['cleaned_text'].progress_apply(lambda x: remove_numbers(x))
#       <a href='vscode-notebook-cell:/Users/spicy.kev/Documents/github/ussc_text_classification/text_cleaning_and_eda.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> df['cleaned_text'] = df['cleaned_text'].progress_apply(lambda x: remove_punctuation(x))
#
# /Users/spicy.kev/Documents/github/ussc_text_classification/text_cleaning_and_eda.ipynb Cell 5 in convert_to_lower(text)
#       <a href='vscode-notebook-cell:/Users/spicy.kev/Documents/github/ussc_text_classification/text_cleaning_and_eda.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> def convert_to_lower(text):
# ----> <a href='vscode-notebook-cell:/Users/spicy.kev/Documents/github/ussc_text_classification/text_cleaning_and_eda.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a>     return text.lower()
#
# AttributeError: 'float' object has no attribute 'lower'

# %%
df['num_words'] = df['cleaned_text'].progress_apply(lambda x: len(x.split()))
# Out:
#   0%|          | 0/61314 [00:00<?, ?it/s]

# %%
df.head(25)
# Out:
#     date_filed plain_text                                               html  \
# 0   1773-09-01       None  <p class="case_cite">1 U.S. 20</p>\r\n    <p c...
# 1   1773-04-01       None  <p class="case_cite">1 U.S. 18</p>\r\n    <p c...
# 2   1787-06-01       None  <p class="case_cite">1 U.S. 194</p>\n    <p cl...
# 3   1787-09-01       None  <p class="case_cite">1 U.S. 210</p>\r\n    <p ...
# 4   1787-04-01       None  <p class="case_cite">2 U.S. 97</p>\n    <p cla...
# 5   1780-04-01       None  <p class="case_cite">1 U.S. 47</p>\n    <p cla...
# 6   1780-04-01       None  <p class="case_cite">1 U.S. 49</p>\r\n    <p c...
# 7   1789-09-01       None  <p class="case_cite">1 U.S. 441</p>\n    <p cl...
# 8   1789-01-01       None  <p class="case_cite">1 U.S. 406</p>\n    <p cl...
# 9   1789-12-01       None  <p class="case_cite">1 U.S. 480</p>\n    <p cl...
# 10  1789-03-01       None  <p class="case_cite">1 U.S. 411</p>\n    <p cl...
# 11  1789-06-01       None  <p class="case_cite">1 U.S. 439</p>\n    <p cl...
# 12  1789-04-01       None  <p class="case_cite">2 U.S. 102</p>\n    <p cl...
# 13  1788-07-01       None  <p class="case_cite">1 U.S. 335</p>\n    <p cl...
# 14  1788-03-01       None  <p class="case_cite">1 U.S. 238</p>\n    <p cl...
# 15  1788-03-01       None  <p class="case_cite">1 U.S. 248</p>\n    <p cl...
# 16  1788-09-01       None  <p class="case_cite">1 U.S. 347</p>\n    <p cl...
# 17  1788-12-01       None  <p class="case_cite">1 U.S. 364</p>\n    <p cl...
# 18  1788-05-01       None  <p class="case_cite">2 U.S. 98</p>\n    <p cla...
# 19  1788-05-01       None  <p class="case_cite">2 U.S. 43</p>\n    <p cla...
# 20  1788-04-01       None  <p class="case_cite">1 U.S. 265</p>\n    <p cl...
# 21  1788-01-01       None  <p class="case_cite">1 U.S. 229</p>\n    <p cl...
# 22  1788-02-01       None  <p class="case_cite">1 U.S. 236</p>\n    <p cl...
# 23  1788-06-01       None  <p class="case_cite">1 U.S. 293</p>\n    <p cl...
# 24  1781-11-01       None  <p class="case_cite">2 U.S. 88</p>\n    <p cla...
#
#                                   html_with_citations  label  \
# 0   <p class="case_cite"><span class="citation no-...   1700
# 1   <p class="case_cite"><span class="citation no-...   1700
# 2   <div>\n<center><b><span class="citation no-lin...   1700
# 3   <div>\n<center><b><span class="citation no-lin...   1700
# 4   <p class="case_cite"><span class="citation no-...   1700
# 5   <p class="case_cite"><span class="citation no-...   1700
# 6   <div>\n<center><b><span class="citation no-lin...   1700
# 7   <p class="case_cite"><span class="citation no-...   1700
# 8   <p class="case_cite"><span class="citation no-...   1700
# 9   <div>\n<center><b><span class="citation no-lin...   1700
# 10  <p class="case_cite"><span class="citation no-...   1700
# 11  <p class="case_cite"><span class="citation no-...   1700
# 12  <div>\n<center><b><span class="citation no-lin...   1700
# 13  <div>\n<center><b><span class="citation no-lin...   1700
# 14  <div>\n<center><b><span class="citation no-lin...   1700
# 15  <p class="case_cite"><span class="citation no-...   1700
# 16  <p class="case_cite"><span class="citation no-...   1700
# 17  <div>\n<center><b><span class="citation no-lin...   1700
# 18  <p class="case_cite"><span class="citation no-...   1700
# 19  <p class="case_cite"><span class="citation no-...   1700
# 20  <p class="case_cite"><span class="citation no-...   1700
# 21  <p class="case_cite"><span class="citation no-...   1700
# 22  <div>\n<center><b><span class="citation no-lin...   1700
# 23  <p class="case_cite"><span class="citation no-...   1700
# 24  <p class="case_cite"><span class="citation no-...   1700
#
#                                          cleaned_text  text_length  num_words
# 0   us dall led anonymous supreme court pennsylvan...          499         69
# 1   us dall led lessee proprietaryvralston supreme...         1652        222
# 2   us dall gerard versus la coste et al supreme c...         4243        586
# 3   us dall pollard versus shaaffer supreme court ...         8914       1274
# 4   us dall led pringlevblacks executors supreme c...          564         77
# 5   us dall led jamess claim april term us dall le...         1559        234
# 6   us dall montgomery versus henry et al supreme ...         3411        462
# 7   us dall led mcullough asigneevhouston supreme ...         5416        719
# 8   us dall led johnsonvhocker supreme court penns...         5852        809
# 9   us dall lyle admor versus foreman supreme cour...          554         68
# 10  us dall led schlosservlesher court common plea...         5814        776
# 11  us dall led phillipsvhyde court common pleas p...          810        111
# 12  us dall hoare versus allen tertenants supreme ...        10721       1477
# 13  us dall respublica v teischer supreme court un...         1133        148
# 14  us dall poultney et al versus ross supreme cou...         1703        227
# 15  us dall led wallace surv partvfitzsimmons sp b...         4010        518
# 16  us dall led geyervsmith court common pleas phi...         1102        145
# 17  us dall kunckle versus kunckle supreme court u...         3023        413
# 18  us dall led mccurdyvpotts et al supreme court ...         2487        327
# 19  us dall led boinodvpelosi philadelphia court c...         1423        189
# 20  us dall led waltonvwillis supreme court pennsy...          538         73
# 21  us dall led millarvhall supreme court pennsylv...         7002        884
# 22  us dall respublica versus shaffer supreme cour...         2692        358
# 23  us dall led tettervrapesnyder court common ple...         1299        171
# 24  us dall led respublicavweidle supreme court pe...         4574        581

# %%
fig = px.histogram(df,
    x=df.index,
    y='num_words',
    nbins=100,
    color='label',
    template='plotly_white')
fig.update_layout(
    title={'text': "Lengths of the Text Opinions (minus punctuation, numbers, stopwords)",
    'x': 0.5,
    'xanchor': 'center'})
fig.update_yaxes(title='Text Lengths')
fig.update_xaxes(showticksuffix="none")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/spicy.kev/Documents/github/ussc_text_classification/text_cleaning_and_eda.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/spicy.kev/Documents/github/ussc_text_classification/text_cleaning_and_eda.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> fig = px.histogram(df,
#       <a href='vscode-notebook-cell:/Users/spicy.kev/Documents/github/ussc_text_classification/text_cleaning_and_eda.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a>     x=df.index,
#       <a href='vscode-notebook-cell:/Users/spicy.kev/Documents/github/ussc_text_classification/text_cleaning_and_eda.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a>     y='num_words',
#       <a href='vscode-notebook-cell:/Users/spicy.kev/Documents/github/ussc_text_classification/text_cleaning_and_eda.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a>     nbins=100,
#       <a href='vscode-notebook-cell:/Users/spicy.kev/Documents/github/ussc_text_classification/text_cleaning_and_eda.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a>     color='label',
#       <a href='vscode-notebook-cell:/Users/spicy.kev/Documents/github/ussc_text_classification/text_cleaning_and_eda.ipynb#X10sZmlsZQ%3D%3D?line=5'>6</a>     template='plotly_white')
#       <a href='vscode-notebook-cell:/Users/spicy.kev/Documents/github/ussc_text_classification/text_cleaning_and_eda.ipynb#X10sZmlsZQ%3D%3D?line=6'>7</a> fig.update_layout(
#       <a href='vscode-notebook-cell:/Users/spicy.kev/Documents/github/ussc_text_classification/text_cleaning_and_eda.ipynb#X10sZmlsZQ%3D%3D?line=7'>8</a>     title={'text': "Lengths of the Text Opinions (minus punctuation, numbers, stopwords)",
#       <a href='vscode-notebook-cell:/Users/spicy.kev/Documents/github/ussc_text_classification/text_cleaning_and_eda.ipynb#X10sZmlsZQ%3D%3D?line=8'>9</a>     'x': 0.5,
#      <a href='vscode-notebook-cell:/Users/spicy.kev/Documents/github/ussc_text_classification/text_cleaning_and_eda.ipynb#X10sZmlsZQ%3D%3D?line=9'>10</a>     'xanchor': 'center'})
#      <a href='vscode-notebook-cell:/Users/spicy.kev/Documents/github/ussc_text_classification/text_cleaning_and_eda.ipynb#X10sZmlsZQ%3D%3D?line=10'>11</a> fig.update_yaxes(title='Text Lengths')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py:472, in histogram(data_frame, x, y, color, pattern_shape, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, pattern_shape_sequence, pattern_shape_map, marginal, opacity, orientation, barmode, barnorm, histnorm, log_x, log_y, range_x, range_y, histfunc, cumulative, nbins, text_auto, title, template, width, height)
#     426 def histogram(
#     427     data_frame=None,
#     428     x=None,
#    (...)
#     464     height=None,
#     465 ):
#     466     """
#     467     In a histogram, rows of `data_frame` are grouped together into a
#     468     rectangular mark to visualize the 1D distribution of an aggregate
#     469     function `histfunc` (e.g. the count or sum) of the value `y` (or `x` if
#     470     `orientation` is `'h'`).
#     471     """
# --> 472     return make_figure(
#     473         args=locals(),
#     474         constructor=go.Histogram,
#     475         trace_patch=dict(
#     476             histnorm=histnorm, histfunc=histfunc, cumulative=dict(enabled=cumulative),
#     477         ),
#     478         layout_patch=dict(barmode=barmode, barnorm=barnorm),
#     479     )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py:1945, in make_figure(args, constructor, trace_patch, layout_patch)
#    1942 layout_patch = layout_patch or {}
#    1943 apply_default_cascade(args)
# -> 1945 args = build_dataframe(args, constructor)
#    1946 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    1947     args = process_dataframe_hierarchy(args)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py:1405, in build_dataframe(args, constructor)
#    1402     args["color"] = None
#    1403 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1405 df_output, wide_id_vars = process_args_into_dataframe(
#    1406     args, wide_mode, var_name, value_name
#    1407 )
#    1409 # now that `df_output` exists and `args` contains only references, we complete
#    1410 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1411 # df_output
#    1413 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py:1207, in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1205         if argument == "index":
#    1206             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1207         raise ValueError(err_msg)
#    1208 elif length and len(df_input[argument]) != length:
#    1209     raise ValueError(
#    1210         "All arguments should have the same length. "
#    1211         "The length of column argument `df[%s]` is %d, whereas the "
#    (...)
#    1218         )
#    1219     )
#
# ValueError: Value of 'y' is not the name of a column in 'data_frame'. Expected one of ['date_filed', 'plain_text', 'html', 'html_with_citations', 'label', 'cleaned_text'] but received: num_words

# %%
plt.style.use('dark_background')
df['label'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df_1700_num_words = df.query('label == 1700')['num_words']
df_1700_num_words.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df_for_training = df[['date_filed', 'label', 'cleaned_text']]
df_for_training.to_json('training_dataframe.json', orient='records')
