# %%
import numpy as np
import pandas as pd
import random
import spacy
from tqdm.auto import tqdm
from spacy.tokens import DocBin
nlp = spacy.load('en_core_web_lg', disable=['tagger', 'parser', 'attribute_ruler' 'ner', 'lemmatizer'])
from spacy.util import minibatch
# Out:
# c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
print(nlp.pipe_names)
nlp.add_pipe('textcat')
# Out:
# ['tok2vec', 'attribute_ruler', 'ner']

# %%
textcat = nlp.get_pipe('textcat')
textcat.add_label("1700")
textcat.add_label("1800")
textcat.add_label("1900")
textcat.add_label("2000")
# Out:
# 1

# %%
textcat.labels
# Out:
# ('1700', '1800', '1900', '2000')

# %%
df = pd.read_json('training_json_file.json')
df.head()
df['cleaned_html'].replace('', np.nan, inplace=True)
df.dropna(subset=['cleaned_html'], inplace=True)
df.head()
# Out:
#                                         cleaned_html  label
# 1  1 U.S. 20 1 Dall. 20 1 L.Ed. 19 ANONYMOUS. No....   1700
# 2  1 U.S. 18 1 Dall. 18 1 L.Ed. 18 The Lessee of ...   1700
# 3  1 U.S. 194 1 Dall. 194 1 L.Ed. 96 Gerardv.La C...   1700
# 4  1 U.S. 210 1 Dall. 210 1 L.Ed. 104 Pollardv.Sh...   1700
# 5  2 U.S. 97 2 Dall. 97 1 L.Ed. 305 Pringlev.Blac...   1700

# %%
train_texts = df['cleaned_html'].values
train_labels = [{"cats": {"1700": label == 1700,
                        "1800": label==1800,
                        "1900": label==1900,
                        "2000": label==2000}} for label in df['label']]

# %%
train_data = list(zip(train_texts, train_labels))
train_data[0]
# Out:
# ('1 U.S. 20 1 Dall. 20 1 L.Ed. 19 ANONYMOUS. No. ____. Supreme Court of Pennsylvania September Term, 1773.  John Fisher, having two sons and a Daughter, made his will, and devised a plantation to his son Matthias in fee. Matthias dies in his minority, intestate, and without issue. Question: whether his heirs at common law shall take; or it shall divide among his other brothers and sisters, under the supplemental intestate law of this Province? On a trial in ejectment for the plantation, it was agreed by council, that the opinion of the Court should be conclusive to the Jury. Mr. Justice WILLING and Justice LAWRENCE were of opinion, and so delivered it to the Jury, that the estate should be divided: and the plaintiff suffered a nonsuit.*    *  Determined at Bucks, Ni, Pri. 15 Oct. 1773.   ',
#  {'cats': {'1700': True, '1800': False, '1900': False, '2000': False}})

# %%
from spacy.training import Example

def train(model, train_data, optimizer, batch_size=8):
    losses = {}
    random.seed(1)
    random.shuffle(train_data)

    for batch in minibatch(train_data, size=batch_size):
        for text, labels in batch:
            doc = nlp.make_doc(text)
            example = Example.from_dict(doc, labels)
            # Update model with texts and labels
            model.update([example], sgd=optimizer, losses=losses)

    return losses

# %%
optimizer = nlp.create_optimizer()

# This may take a while to run!
losses = train(nlp, train_data, optimizer)
print(losses['textcat'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\KSpicer\Documents\GitHub\bulk_scotus\spacy_training_script_notebook.ipynb Cell 9 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/KSpicer/Documents/GitHub/bulk_scotus/spacy_training_script_notebook.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> optimizer = nlp.create_optimizer()
#       <a href='vscode-notebook-cell:/c%3A/Users/KSpicer/Documents/GitHub/bulk_scotus/spacy_training_script_notebook.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> # This may take a while to run!
# ----> <a href='vscode-notebook-cell:/c%3A/Users/KSpicer/Documents/GitHub/bulk_scotus/spacy_training_script_notebook.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a> losses = train(nlp, train_data, optimizer)
#       <a href='vscode-notebook-cell:/c%3A/Users/KSpicer/Documents/GitHub/bulk_scotus/spacy_training_script_notebook.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a> print(losses['textcat'])
#
# c:\Users\KSpicer\Documents\GitHub\bulk_scotus\spacy_training_script_notebook.ipynb Cell 9 in train(model, train_data, optimizer, batch_size)
#      <a href='vscode-notebook-cell:/c%3A/Users/KSpicer/Documents/GitHub/bulk_scotus/spacy_training_script_notebook.ipynb#X11sZmlsZQ%3D%3D?line=10'>11</a>         example = Example.from_dict(doc, labels)
#      <a href='vscode-notebook-cell:/c%3A/Users/KSpicer/Documents/GitHub/bulk_scotus/spacy_training_script_notebook.ipynb#X11sZmlsZQ%3D%3D?line=11'>12</a>         # Update model with texts and labels
# ---> <a href='vscode-notebook-cell:/c%3A/Users/KSpicer/Documents/GitHub/bulk_scotus/spacy_training_script_notebook.ipynb#X11sZmlsZQ%3D%3D?line=12'>13</a>         model.update([example], sgd=optimizer, losses=losses)
#      <a href='vscode-notebook-cell:/c%3A/Users/KSpicer/Documents/GitHub/bulk_scotus/spacy_training_script_notebook.ipynb#X11sZmlsZQ%3D%3D?line=14'>15</a> return losses
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\spacy\language.py:1164, in Language.update(self, examples, _, drop, sgd, losses, component_cfg, exclude, annotates)
#    1161 for name, proc in self.pipeline:
#    1162     # ignore statements are used here because mypy ignores hasattr
#    1163     if name not in exclude and hasattr(proc, "update"):
# -> 1164         proc.update(examples, sgd=None, losses=losses, **component_cfg[name])  # type: ignore
#    1165     if sgd not in (None, False):
#    1166         if (
#    1167             name not in exclude
#    1168             and isinstance(proc, ty.TrainableComponent)
#    1169             and proc.is_trainable
#    1170             and proc.model not in (True, False, None)
#    1171         ):
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\spacy\pipeline\textcat.py:243, in TextCategorizer.update(self, examples, drop, sgd, losses)
#     241     return losses
#     242 set_dropout_rate(self.model, drop)
# --> 243 scores, bp_scores = self.model.begin_update([eg.predicted for eg in examples])
#     244 loss, d_scores = self.get_loss(examples, scores)
#     245 bp_scores(d_scores)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\model.py:309, in Model.begin_update(self, X)
#     302 def begin_update(self, X: InT) -> Tuple[OutT, Callable[[InT], OutT]]:
#     303     """Run the model over a batch of data, returning the output and a
#     304     callback to complete the backward pass. A tuple (Y, finish_update),
#     305     where Y is a batch of output data, and finish_update is a callback that
#     306     takes the gradient with respect to the output and an optimizer function,
#     307     and returns the gradient with respect to the input.
#     308     """
# --> 309     return self._func(self, X, is_train=True)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\layers\chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\layers\concatenate.py:44, in forward(model, X, is_train)
#      43 def forward(model: Model[InT, OutT], X: InT, is_train: bool) -> Tuple[OutT, Callable]:
# ---> 44     Ys, callbacks = zip(*[layer(X, is_train=is_train) for layer in model.layers])
#      45     if isinstance(Ys[0], list):
#      46         data_l, backprop = _list_forward(model, X, Ys, callbacks, is_train)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\layers\concatenate.py:44, in <listcomp>(.0)
#      43 def forward(model: Model[InT, OutT], X: InT, is_train: bool) -> Tuple[OutT, Callable]:
# ---> 44     Ys, callbacks = zip(*[layer(X, is_train=is_train) for layer in model.layers])
#      45     if isinstance(Ys[0], list):
#      46         data_l, backprop = _list_forward(model, X, Ys, callbacks, is_train)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\layers\chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\layers\with_cpu.py:24, in forward(model, X, is_train)
#      23 def forward(model: Model, X: Any, is_train: bool) -> Tuple[Any, Callable]:
# ---> 24     cpu_outputs, backprop = model.layers[0].begin_update(_to_cpu(X))
#      25     gpu_outputs = _to_device(model.ops, cpu_outputs)
#      27     def with_cpu_backprop(d_outputs):
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\model.py:309, in Model.begin_update(self, X)
#     302 def begin_update(self, X: InT) -> Tuple[OutT, Callable[[InT], OutT]]:
#     303     """Run the model over a batch of data, returning the output and a
#     304     callback to complete the backward pass. A tuple (Y, finish_update),
#     305     where Y is a batch of output data, and finish_update is a callback that
#     306     takes the gradient with respect to the output and an optimizer function,
#     307     and returns the gradient with respect to the input.
#     308     """
# --> 309     return self._func(self, X, is_train=True)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\layers\chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\layers\resizable.py:26, in forward(model, X, is_train)
#      24 def forward(model: Model[InT, OutT], X: InT, is_train: bool):
#      25     layer = model.layers[0]
# ---> 26     Y, callback = layer(X, is_train=is_train)
#      28     def backprop(dY: OutT) -> InT:
#      29         return callback(dY)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\layers\sparselinear.pyx:43, in thinc.layers.sparselinear.forward()
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\layers\sparselinear.pyx:68, in thinc.layers.sparselinear._begin_cpu_update()
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\model.py:175, in Model.get_dim(self, name)
#     173 if value is None:
#     174     err = f"Cannot get dimension '{name}' for model '{self.name}': value unset"
# --> 175     raise ValueError(err)
#     176 else:
#     177     return value
#
# ValueError: Cannot get dimension 'nO' for model 'sparse_linear': value unset

# %%
spacy.util.fix_random_seed(1)
from spacy.training import Example

optimizer = nlp.create_optimizer()

for batch in spacy.util.minibatch(train_data, size=8):
    for text, labels in batch:
        doc = nlp.make_doc(text)
        example = Example.from_dict(doc, labels)
        nlp.update([example], sgd=optimizer)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\KSpicer\Documents\GitHub\bulk_scotus\spacy_training_script_notebook.ipynb Cell 8 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/KSpicer/Documents/GitHub/bulk_scotus/spacy_training_script_notebook.ipynb#X11sZmlsZQ%3D%3D?line=7'>8</a> doc = nlp.make_doc(text)
#       <a href='vscode-notebook-cell:/c%3A/Users/KSpicer/Documents/GitHub/bulk_scotus/spacy_training_script_notebook.ipynb#X11sZmlsZQ%3D%3D?line=8'>9</a> example = Example.from_dict(doc, labels)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/KSpicer/Documents/GitHub/bulk_scotus/spacy_training_script_notebook.ipynb#X11sZmlsZQ%3D%3D?line=9'>10</a> nlp.update([example], sgd=optimizer)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\spacy\language.py:1164, in Language.update(self, examples, _, drop, sgd, losses, component_cfg, exclude, annotates)
#    1161 for name, proc in self.pipeline:
#    1162     # ignore statements are used here because mypy ignores hasattr
#    1163     if name not in exclude and hasattr(proc, "update"):
# -> 1164         proc.update(examples, sgd=None, losses=losses, **component_cfg[name])  # type: ignore
#    1165     if sgd not in (None, False):
#    1166         if (
#    1167             name not in exclude
#    1168             and isinstance(proc, ty.TrainableComponent)
#    1169             and proc.is_trainable
#    1170             and proc.model not in (True, False, None)
#    1171         ):
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\spacy\pipeline\textcat.py:243, in TextCategorizer.update(self, examples, drop, sgd, losses)
#     241     return losses
#     242 set_dropout_rate(self.model, drop)
# --> 243 scores, bp_scores = self.model.begin_update([eg.predicted for eg in examples])
#     244 loss, d_scores = self.get_loss(examples, scores)
#     245 bp_scores(d_scores)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\model.py:309, in Model.begin_update(self, X)
#     302 def begin_update(self, X: InT) -> Tuple[OutT, Callable[[InT], OutT]]:
#     303     """Run the model over a batch of data, returning the output and a
#     304     callback to complete the backward pass. A tuple (Y, finish_update),
#     305     where Y is a batch of output data, and finish_update is a callback that
#     306     takes the gradient with respect to the output and an optimizer function,
#     307     and returns the gradient with respect to the input.
#     308     """
# --> 309     return self._func(self, X, is_train=True)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\layers\chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\layers\concatenate.py:44, in forward(model, X, is_train)
#      43 def forward(model: Model[InT, OutT], X: InT, is_train: bool) -> Tuple[OutT, Callable]:
# ---> 44     Ys, callbacks = zip(*[layer(X, is_train=is_train) for layer in model.layers])
#      45     if isinstance(Ys[0], list):
#      46         data_l, backprop = _list_forward(model, X, Ys, callbacks, is_train)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\layers\concatenate.py:44, in <listcomp>(.0)
#      43 def forward(model: Model[InT, OutT], X: InT, is_train: bool) -> Tuple[OutT, Callable]:
# ---> 44     Ys, callbacks = zip(*[layer(X, is_train=is_train) for layer in model.layers])
#      45     if isinstance(Ys[0], list):
#      46         data_l, backprop = _list_forward(model, X, Ys, callbacks, is_train)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\layers\chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\layers\with_cpu.py:24, in forward(model, X, is_train)
#      23 def forward(model: Model, X: Any, is_train: bool) -> Tuple[Any, Callable]:
# ---> 24     cpu_outputs, backprop = model.layers[0].begin_update(_to_cpu(X))
#      25     gpu_outputs = _to_device(model.ops, cpu_outputs)
#      27     def with_cpu_backprop(d_outputs):
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\model.py:309, in Model.begin_update(self, X)
#     302 def begin_update(self, X: InT) -> Tuple[OutT, Callable[[InT], OutT]]:
#     303     """Run the model over a batch of data, returning the output and a
#     304     callback to complete the backward pass. A tuple (Y, finish_update),
#     305     where Y is a batch of output data, and finish_update is a callback that
#     306     takes the gradient with respect to the output and an optimizer function,
#     307     and returns the gradient with respect to the input.
#     308     """
# --> 309     return self._func(self, X, is_train=True)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\layers\chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\layers\resizable.py:26, in forward(model, X, is_train)
#      24 def forward(model: Model[InT, OutT], X: InT, is_train: bool):
#      25     layer = model.layers[0]
# ---> 26     Y, callback = layer(X, is_train=is_train)
#      28     def backprop(dY: OutT) -> InT:
#      29         return callback(dY)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\layers\sparselinear.pyx:43, in thinc.layers.sparselinear.forward()
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\layers\sparselinear.pyx:68, in thinc.layers.sparselinear._begin_cpu_update()
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\model.py:175, in Model.get_dim(self, name)
#     173 if value is None:
#     174     err = f"Cannot get dimension '{name}' for model '{self.name}': value unset"
# --> 175     raise ValueError(err)
#     176 else:
#     177     return value
#
# ValueError: Cannot get dimension 'nO' for model 'sparse_linear': value unset

# %%
def make_docs(data):

    docs = []
    for doc, label in tqdm(nlp.pipe(data, as_tuples=True), total=len(data)):
        doc.cats['positive]'] = label
        docs.append(doc)
    return(docs)

# %%
df = pd.read_json('training_json_file.json')

# %%
df.head()
# Out:
#                                         cleaned_html  label
# 0                                                      1700
# 1  1 U.S. 20 1 Dall. 20 1 L.Ed. 19 ANONYMOUS. No....   1700
# 2  1 U.S. 18 1 Dall. 18 1 L.Ed. 18 The Lessee of ...   1700
# 3  1 U.S. 194 1 Dall. 194 1 L.Ed. 96 Gerardv.La C...   1700
# 4  1 U.S. 210 1 Dall. 210 1 L.Ed. 104 Pollardv.Sh...   1700

# %%
data = list(zip(df['cleaned_html'], df['label']))
print(len(data))
# Out:
# 63374

# %%
num_texts = 500
train_data = random.sample(data, num_texts)
train_docs = make_docs(train_data)
doc_bin = DocBin(docs=train_docs)
doc_bin.to_disk('train.spacy')

valid_data = random.sample(data, num_texts)
valid_docs = make_docs(valid_data)
doc_bin = DocBin(docs=valid_docs)
doc_bin.to_disk('valid.spacy')
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\KSpicer\Documents\GitHub\bulk_scotus\spacy_training_script_notebook.ipynb Cell 10 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/KSpicer/Documents/GitHub/bulk_scotus/spacy_training_script_notebook.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> num_texts = 500
#       <a href='vscode-notebook-cell:/c%3A/Users/KSpicer/Documents/GitHub/bulk_scotus/spacy_training_script_notebook.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> train_data = random.sample(data, num_texts)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/KSpicer/Documents/GitHub/bulk_scotus/spacy_training_script_notebook.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> train_docs = make_docs(train_data)
#       <a href='vscode-notebook-cell:/c%3A/Users/KSpicer/Documents/GitHub/bulk_scotus/spacy_training_script_notebook.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> doc_bin = DocBin(docs=train_docs)
#       <a href='vscode-notebook-cell:/c%3A/Users/KSpicer/Documents/GitHub/bulk_scotus/spacy_training_script_notebook.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> doc_bin.to_disk('train.spacy')
#
# c:\Users\KSpicer\Documents\GitHub\bulk_scotus\spacy_training_script_notebook.ipynb Cell 10 in make_docs(data)
#       <a href='vscode-notebook-cell:/c%3A/Users/KSpicer/Documents/GitHub/bulk_scotus/spacy_training_script_notebook.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> def make_docs(data):
#       <a href='vscode-notebook-cell:/c%3A/Users/KSpicer/Documents/GitHub/bulk_scotus/spacy_training_script_notebook.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a>     docs = []
# ----> <a href='vscode-notebook-cell:/c%3A/Users/KSpicer/Documents/GitHub/bulk_scotus/spacy_training_script_notebook.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a>     for doc, label in tqdm(nlp.pipe(data, as_tuples=True), total=len(data)):
#       <a href='vscode-notebook-cell:/c%3A/Users/KSpicer/Documents/GitHub/bulk_scotus/spacy_training_script_notebook.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a>         doc.cats['positive]'] = label
#       <a href='vscode-notebook-cell:/c%3A/Users/KSpicer/Documents/GitHub/bulk_scotus/spacy_training_script_notebook.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a>         docs.append(doc)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\tqdm\notebook.py:258, in tqdm_notebook.__iter__(self)
#     256 try:
#     257     it = super(tqdm_notebook, self).__iter__()
# --> 258     for obj in it:
#     259         # return super(tqdm...) will not catch exception
#     260         yield obj
#     261 # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\tqdm\std.py:1195, in tqdm.__iter__(self)
#    1192 time = self._time
#    1194 try:
# -> 1195     for obj in iterable:
#    1196         yield obj
#    1197         # Update and possibly print the progressbar.
#    1198         # Note: does not call self.update(1) for speed optimisation.
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\spacy\language.py:1539, in Language.pipe(self, texts, as_tuples, batch_size, disable, component_cfg, n_process)
#    1529 docs_with_contexts = (
#    1530     self._ensure_doc_with_context(text, context) for text, context in texts
#    1531 )
#    1532 docs = self.pipe(
#    1533     docs_with_contexts,
#    1534     batch_size=batch_size,
#    (...)
#    1537     component_cfg=component_cfg,
#    1538 )
# -> 1539 for doc in docs:
#    1540     context = doc._context
#    1541     doc._context = None
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\spacy\language.py:1583, in Language.pipe(self, texts, as_tuples, batch_size, disable, component_cfg, n_process)
#    1581     for pipe in pipes:
#    1582         docs = pipe(docs)
# -> 1583 for doc in docs:
#    1584     yield doc
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\spacy\util.py:1639, in _pipe(docs, proc, name, default_error_handler, kwargs)
#    1631 def _pipe(
#    1632     docs: Iterable["Doc"],
#    1633     proc: "Pipe",
#    (...)
#    1636     kwargs: Mapping[str, Any],
#    1637 ) -> Iterator["Doc"]:
#    1638     if hasattr(proc, "pipe"):
# -> 1639         yield from proc.pipe(docs, **kwargs)
#    1640     else:
#    1641         # We added some args for pipe that __call__ doesn't expect.
#    1642         kwargs = dict(kwargs)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\spacy\pipeline\trainable_pipe.pyx:73, in pipe()
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\spacy\util.py:1588, in minibatch(items, size)
#    1586 while True:
#    1587     batch_size = next(size_)
# -> 1588     batch = list(itertools.islice(items, int(batch_size)))
#    1589     if len(batch) == 0:
#    1590         break
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\spacy\util.py:1639, in _pipe(docs, proc, name, default_error_handler, kwargs)
#    1631 def _pipe(
#    1632     docs: Iterable["Doc"],
#    1633     proc: "Pipe",
#    (...)
#    1636     kwargs: Mapping[str, Any],
#    1637 ) -> Iterator["Doc"]:
#    1638     if hasattr(proc, "pipe"):
# -> 1639         yield from proc.pipe(docs, **kwargs)
#    1640     else:
#    1641         # We added some args for pipe that __call__ doesn't expect.
#    1642         kwargs = dict(kwargs)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\spacy\pipeline\transition_parser.pyx:233, in pipe()
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\spacy\util.py:1588, in minibatch(items, size)
#    1586 while True:
#    1587     batch_size = next(size_)
# -> 1588     batch = list(itertools.islice(items, int(batch_size)))
#    1589     if len(batch) == 0:
#    1590         break
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\spacy\util.py:1639, in _pipe(docs, proc, name, default_error_handler, kwargs)
#    1631 def _pipe(
#    1632     docs: Iterable["Doc"],
#    1633     proc: "Pipe",
#    (...)
#    1636     kwargs: Mapping[str, Any],
#    1637 ) -> Iterator["Doc"]:
#    1638     if hasattr(proc, "pipe"):
# -> 1639         yield from proc.pipe(docs, **kwargs)
#    1640     else:
#    1641         # We added some args for pipe that __call__ doesn't expect.
#    1642         kwargs = dict(kwargs)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\spacy\pipeline\pipe.pyx:53, in pipe()
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\spacy\util.py:1639, in _pipe(docs, proc, name, default_error_handler, kwargs)
#    1631 def _pipe(
#    1632     docs: Iterable["Doc"],
#    1633     proc: "Pipe",
#    (...)
#    1636     kwargs: Mapping[str, Any],
#    1637 ) -> Iterator["Doc"]:
#    1638     if hasattr(proc, "pipe"):
# -> 1639         yield from proc.pipe(docs, **kwargs)
#    1640     else:
#    1641         # We added some args for pipe that __call__ doesn't expect.
#    1642         kwargs = dict(kwargs)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\spacy\pipeline\pipe.pyx:53, in pipe()
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\spacy\util.py:1639, in _pipe(docs, proc, name, default_error_handler, kwargs)
#    1631 def _pipe(
#    1632     docs: Iterable["Doc"],
#    1633     proc: "Pipe",
#    (...)
#    1636     kwargs: Mapping[str, Any],
#    1637 ) -> Iterator["Doc"]:
#    1638     if hasattr(proc, "pipe"):
# -> 1639         yield from proc.pipe(docs, **kwargs)
#    1640     else:
#    1641         # We added some args for pipe that __call__ doesn't expect.
#    1642         kwargs = dict(kwargs)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\spacy\pipeline\transition_parser.pyx:233, in pipe()
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\spacy\util.py:1588, in minibatch(items, size)
#    1586 while True:
#    1587     batch_size = next(size_)
# -> 1588     batch = list(itertools.islice(items, int(batch_size)))
#    1589     if len(batch) == 0:
#    1590         break
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\spacy\util.py:1639, in _pipe(docs, proc, name, default_error_handler, kwargs)
#    1631 def _pipe(
#    1632     docs: Iterable["Doc"],
#    1633     proc: "Pipe",
#    (...)
#    1636     kwargs: Mapping[str, Any],
#    1637 ) -> Iterator["Doc"]:
#    1638     if hasattr(proc, "pipe"):
# -> 1639         yield from proc.pipe(docs, **kwargs)
#    1640     else:
#    1641         # We added some args for pipe that __call__ doesn't expect.
#    1642         kwargs = dict(kwargs)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\spacy\pipeline\trainable_pipe.pyx:73, in pipe()
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\spacy\util.py:1588, in minibatch(items, size)
#    1586 while True:
#    1587     batch_size = next(size_)
# -> 1588     batch = list(itertools.islice(items, int(batch_size)))
#    1589     if len(batch) == 0:
#    1590         break
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\spacy\util.py:1639, in _pipe(docs, proc, name, default_error_handler, kwargs)
#    1631 def _pipe(
#    1632     docs: Iterable["Doc"],
#    1633     proc: "Pipe",
#    (...)
#    1636     kwargs: Mapping[str, Any],
#    1637 ) -> Iterator["Doc"]:
#    1638     if hasattr(proc, "pipe"):
# -> 1639         yield from proc.pipe(docs, **kwargs)
#    1640     else:
#    1641         # We added some args for pipe that __call__ doesn't expect.
#    1642         kwargs = dict(kwargs)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\spacy\pipeline\trainable_pipe.pyx:75, in pipe()
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\spacy\pipeline\tok2vec.py:125, in Tok2Vec.predict(self, docs)
#     123     width = self.model.get_dim("nO")
#     124     return [self.model.ops.alloc((0, width)) for doc in docs]
# --> 125 tokvecs = self.model.predict(docs)
#     126 batch_id = Tok2VecListener.get_batch_id(docs)
#     127 for listener in self.listeners:
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\model.py:315, in Model.predict(self, X)
#     311 def predict(self, X: InT) -> OutT:
#     312     """Call the model's `forward` function with `is_train=False`, and return
#     313     only the output, instead of the `(output, callback)` tuple.
#     314     """
# --> 315     return self._func(self, X, is_train=False)[0]
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\layers\chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\layers\chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\layers\concatenate.py:44, in forward(model, X, is_train)
#      43 def forward(model: Model[InT, OutT], X: InT, is_train: bool) -> Tuple[OutT, Callable]:
# ---> 44     Ys, callbacks = zip(*[layer(X, is_train=is_train) for layer in model.layers])
#      45     if isinstance(Ys[0], list):
#      46         data_l, backprop = _list_forward(model, X, Ys, callbacks, is_train)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\layers\concatenate.py:44, in <listcomp>(.0)
#      43 def forward(model: Model[InT, OutT], X: InT, is_train: bool) -> Tuple[OutT, Callable]:
# ---> 44     Ys, callbacks = zip(*[layer(X, is_train=is_train) for layer in model.layers])
#      45     if isinstance(Ys[0], list):
#      46         data_l, backprop = _list_forward(model, X, Ys, callbacks, is_train)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\layers\chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\layers\with_array.py:32, in forward(model, Xseq, is_train)
#      28 def forward(
#      29     model: Model[SeqT, SeqT], Xseq: SeqT, is_train: bool
#      30 ) -> Tuple[SeqT, Callable]:
#      31     if isinstance(Xseq, Ragged):
# ---> 32         return cast(Tuple[SeqT, Callable], _ragged_forward(model, Xseq, is_train))
#      33     elif isinstance(Xseq, Padded):
#      34         return cast(Tuple[SeqT, Callable], _padded_forward(model, Xseq, is_train))
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\layers\with_array.py:87, in _ragged_forward(model, Xr, is_train)
#      83 def _ragged_forward(
#      84     model: Model[SeqT, SeqT], Xr: Ragged, is_train: bool
#      85 ) -> Tuple[Ragged, Callable]:
#      86     layer: Model[ArrayXd, ArrayXd] = model.layers[0]
# ---> 87     Y, get_dX = layer(Xr.dataXd, is_train)
#      89     def backprop(dYr: Ragged) -> Ragged:
#      90         return Ragged(get_dX(dYr.dataXd), dYr.lengths)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\layers\concatenate.py:52, in forward(model, X, is_train)
#      50     return cast(OutT, data_r), backprop
#      51 else:
# ---> 52     data_a, backprop = _array_forward(model, X, Ys, callbacks, is_train)
#      53     return cast(OutT, data_a), backprop
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\thinc\layers\concatenate.py:60, in _array_forward(model, X, Ys, callbacks, is_train)
#      56 def _array_forward(
#      57     model: Model[InT, OutT], X, Ys: List, callbacks, is_train: bool
#      58 ) -> Tuple[Array2d, Callable]:
#      59     widths = [Y.shape[1] for Y in Ys]
# ---> 60     output = model.ops.xp.hstack(Ys)
#      62     def backprop(d_output: Array2d) -> InT:
#      63         dY = model.ops.as_contig(d_output[:, : widths[0]])
#
# File <__array_function__ internals>:180, in hstack(*args, **kwargs)
#
# File c:\Users\KSpicer\Anaconda3\envs\victorian_authorship_env\lib\site-packages\numpy\core\shape_base.py:345, in hstack(tup)
#     343     return _nx.concatenate(arrs, 0)
#     344 else:
# --> 345     return _nx.concatenate(arrs, 1)
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
y = pd.get_dummies(df['label'], prefix='label')
label = list(y.columns)
print(label)

y = y.to_dict('index')
# Out:
# ['label_1700', 'label_1800', 'label_1900', 'label_2000']

# %%
dataset = list(zip(df['cleaned_html'], [{'cats': cats} for cats in y.values()]))
print(dataset[1])
# Out:
# ('1 U.S. 20 1 Dall. 20 1 L.Ed. 19 ANONYMOUS. No. ____. Supreme Court of Pennsylvania September Term, 1773.  John Fisher, having two sons and a Daughter, made his will, and devised a plantation to his son Matthias in fee. Matthias dies in his minority, intestate, and without issue. Question: whether his heirs at common law shall take; or it shall divide among his other brothers and sisters, under the supplemental intestate law of this Province? On a trial in ejectment for the plantation, it was agreed by council, that the opinion of the Court should be conclusive to the Jury. Mr. Justice WILLING and Justice LAWRENCE were of opinion, and so delivered it to the Jury, that the estate should be divided: and the plaintiff suffered a nonsuit.*    *  Determined at Bucks, Ni, Pri. 15 Oct. 1773.   ', {'cats': {'label_1700': 1, 'label_1800': 0, 'label_1900': 0, 'label_2000': 0}})

# %%
from sklearn.model_selection import train_test_split
train_data, test_data = train_test_split(dataset, train_size=0.8, random_state=13)

textcat = nlp.add_pipe("textcat_multilabel")
for i in label:
    textcat.add_label(i)

# %%
textcat.labels
# Out:
# ('label_1700', 'label_1800', 'label_1900', 'label_2000')

# %%
nlp = spacy.blank('en')
optimizer = nlp.begin_training()
iterations = 2

# %%
from spacy.util import minibatch, compounding
from spacy.training import Example
with nlp.select_pipes(enable="textcat_multilabel"):
    for j in range(iterations):
        losses = {}
        k = 0
        batches = minibatch(train_data, size = compounding(4.,32.,1.001))
        for batch in batches:
            text, annotations = zip(*batch)
            example = []
            for i in range(len(text)):
                doc = nlp.make_doc(text[i])
                example.append(Example.from_dict(doc, annotations[i]))
            nlp.update(example, sgd=optimizer, drop=0.2, losses = losses)
            print(f'Batch No: {k} Loss = {losses}')
            k += 1
        print("\n\n Completed Iterations : {} ".format(j))
# Out:
# Batch No: 0 Loss = {}
# Batch No: 1 Loss = {}
# Batch No: 2 Loss = {}
# Batch No: 3 Loss = {}
# Batch No: 4 Loss = {}
# Batch No: 5 Loss = {}
# Batch No: 6 Loss = {}
# Batch No: 7 Loss = {}
# Batch No: 8 Loss = {}
# Batch No: 9 Loss = {}
# Batch No: 10 Loss = {}
# Batch No: 11 Loss = {}
# Batch No: 12 Loss = {}
# Batch No: 13 Loss = {}
# Batch No: 14 Loss = {}
# Batch No: 15 Loss = {}
# Batch No: 16 Loss = {}
# Batch No: 17 Loss = {}
# Batch No: 18 Loss = {}
# Batch No: 19 Loss = {}
# Batch No: 20 Loss = {}
# Batch No: 21 Loss = {}
# Batch No: 22 Loss = {}
# Batch No: 23 Loss = {}
# Batch No: 24 Loss = {}
# Batch No: 25 Loss = {}
# Batch No: 26 Loss = {}
# Batch No: 27 Loss = {}
# Batch No: 28 Loss = {}
# Batch No: 29 Loss = {}
# Batch No: 30 Loss = {}
# Batch No: 31 Loss = {}
# Batch No: 32 Loss = {}
# Batch No: 33 Loss = {}
# Batch No: 34 Loss = {}
# Batch No: 35 Loss = {}
# Batch No: 36 Loss = {}
# Batch No: 37 Loss = {}
# Batch No: 38 Loss = {}
# Batch No: 39 Loss = {}
# Batch No: 40 Loss = {}
# Batch No: 41 Loss = {}
# Batch No: 42 Loss = {}
# Batch No: 43 Loss = {}
# Batch No: 44 Loss = {}
# Batch No: 45 Loss = {}
# Batch No: 46 Loss = {}
# Batch No: 47 Loss = {}
# Batch No: 48 Loss = {}
# Batch No: 49 Loss = {}
# Batch No: 50 Loss = {}
# Batch No: 51 Loss = {}
# Batch No: 52 Loss = {}
# Batch No: 53 Loss = {}
# Batch No: 54 Loss = {}
# Batch No: 55 Loss = {}
# Batch No: 56 Loss = {}
# Batch No: 57 Loss = {}
# Batch No: 58 Loss = {}
# Batch No: 59 Loss = {}
# Batch No: 60 Loss = {}
# Batch No: 61 Loss = {}
# Batch No: 62 Loss = {}
# Batch No: 63 Loss = {}
# Batch No: 64 Loss = {}
# Batch No: 65 Loss = {}
# Batch No: 66 Loss = {}
# Batch No: 67 Loss = {}
# Batch No: 68 Loss = {}
# Batch No: 69 Loss = {}
# Batch No: 70 Loss = {}
# Batch No: 71 Loss = {}
# Batch No: 72 Loss = {}
# Batch No: 73 Loss = {}
# Batch No: 74 Loss = {}
# Batch No: 75 Loss = {}
# Batch No: 76 Loss = {}
# Batch No: 77 Loss = {}
# Batch No: 78 Loss = {}
# Batch No: 79 Loss = {}
# Batch No: 80 Loss = {}
# Batch No: 81 Loss = {}
# Batch No: 82 Loss = {}
# Batch No: 83 Loss = {}
# Batch No: 84 Loss = {}
# Batch No: 85 Loss = {}
# Batch No: 86 Loss = {}
# Batch No: 87 Loss = {}
# Batch No: 88 Loss = {}
# Batch No: 89 Loss = {}
# Batch No: 90 Loss = {}
# Batch No: 91 Loss = {}
# Batch No: 92 Loss = {}
# Batch No: 93 Loss = {}
# Batch No: 94 Loss = {}
# Batch No: 95 Loss = {}
# Batch No: 96 Loss = {}
# Batch No: 97 Loss = {}
# Batch No: 98 Loss = {}
# Batch No: 99 Loss = {}
# Batch No: 100 Loss = {}
# Batch No: 101 Loss = {}
# Batch No: 102 Loss = {}
# Batch No: 103 Loss = {}
# Batch No: 104 Loss = {}
# Batch No: 105 Loss = {}
# Batch No: 106 Loss = {}
# Batch No: 107 Loss = {}
# Batch No: 108 Loss = {}
# Batch No: 109 Loss = {}
# Batch No: 110 Loss = {}
# Batch No: 111 Loss = {}
# Batch No: 112 Loss = {}
# Batch No: 113 Loss = {}
# Batch No: 114 Loss = {}
# Batch No: 115 Loss = {}
# Batch No: 116 Loss = {}
# Batch No: 117 Loss = {}
# Batch No: 118 Loss = {}
# Batch No: 119 Loss = {}
# Batch No: 120 Loss = {}
# Batch No: 121 Loss = {}
# Batch No: 122 Loss = {}
# Batch No: 123 Loss = {}
# Batch No: 124 Loss = {}
# Batch No: 125 Loss = {}
# Batch No: 126 Loss = {}
# Batch No: 127 Loss = {}
# Batch No: 128 Loss = {}
# Batch No: 129 Loss = {}
# Batch No: 130 Loss = {}
# Batch No: 131 Loss = {}
# Batch No: 132 Loss = {}
# Batch No: 133 Loss = {}
# Batch No: 134 Loss = {}
# Batch No: 135 Loss = {}
# Batch No: 136 Loss = {}
# Batch No: 137 Loss = {}
# Batch No: 138 Loss = {}
# Batch No: 139 Loss = {}
# Batch No: 140 Loss = {}
# Batch No: 141 Loss = {}
# Batch No: 142 Loss = {}
# Batch No: 143 Loss = {}
# Batch No: 144 Loss = {}
# Batch No: 145 Loss = {}
# Batch No: 146 Loss = {}
# Batch No: 147 Loss = {}
# Batch No: 148 Loss = {}
# Batch No: 149 Loss = {}
# Batch No: 150 Loss = {}
# Batch No: 151 Loss = {}
# Batch No: 152 Loss = {}
# Batch No: 153 Loss = {}
# Batch No: 154 Loss = {}
# Batch No: 155 Loss = {}
# Batch No: 156 Loss = {}
# Batch No: 157 Loss = {}
# Batch No: 158 Loss = {}
# Batch No: 159 Loss = {}
# Batch No: 160 Loss = {}
# Batch No: 161 Loss = {}
# Batch No: 162 Loss = {}
# Batch No: 163 Loss = {}
# Batch No: 164 Loss = {}
# Batch No: 165 Loss = {}
# Batch No: 166 Loss = {}
# Batch No: 167 Loss = {}
# Batch No: 168 Loss = {}
# Batch No: 169 Loss = {}
# Batch No: 170 Loss = {}
# Batch No: 171 Loss = {}
# Batch No: 172 Loss = {}
# Batch No: 173 Loss = {}
# Batch No: 174 Loss = {}
# Batch No: 175 Loss = {}
# Batch No: 176 Loss = {}
# Batch No: 177 Loss = {}
# Batch No: 178 Loss = {}
# Batch No: 179 Loss = {}
# Batch No: 180 Loss = {}
# Batch No: 181 Loss = {}
# Batch No: 182 Loss = {}
# Batch No: 183 Loss = {}
# Batch No: 184 Loss = {}
# Batch No: 185 Loss = {}
# Batch No: 186 Loss = {}
# Batch No: 187 Loss = {}
# Batch No: 188 Loss = {}
# Batch No: 189 Loss = {}
# Batch No: 190 Loss = {}
# Batch No: 191 Loss = {}
# Batch No: 192 Loss = {}
# Batch No: 193 Loss = {}
# Batch No: 194 Loss = {}
# Batch No: 195 Loss = {}
# Batch No: 196 Loss = {}
# Batch No: 197 Loss = {}
# Batch No: 198 Loss = {}
# Batch No: 199 Loss = {}
# Batch No: 200 Loss = {}
# Batch No: 201 Loss = {}
# Batch No: 202 Loss = {}
# Batch No: 203 Loss = {}
# Batch No: 204 Loss = {}
# Batch No: 205 Loss = {}
# Batch No: 206 Loss = {}
# Batch No: 207 Loss = {}
# Batch No: 208 Loss = {}
# Batch No: 209 Loss = {}
# Batch No: 210 Loss = {}
# Batch No: 211 Loss = {}
# Batch No: 212 Loss = {}
# Batch No: 213 Loss = {}
# Batch No: 214 Loss = {}
# Batch No: 215 Loss = {}
# Batch No: 216 Loss = {}
# Batch No: 217 Loss = {}
# Batch No: 218 Loss = {}
# Batch No: 219 Loss = {}
# Batch No: 220 Loss = {}
# Batch No: 221 Loss = {}
# Batch No: 222 Loss = {}
# Batch No: 223 Loss = {}
# Batch No: 224 Loss = {}
# Batch No: 225 Loss = {}
# Batch No: 226 Loss = {}
# Batch No: 227 Loss = {}
# Batch No: 228 Loss = {}
# Batch No: 229 Loss = {}
# Batch No: 230 Loss = {}
# Batch No: 231 Loss = {}
# Batch No: 232 Loss = {}
# Batch No: 233 Loss = {}
# Batch No: 234 Loss = {}
# Batch No: 235 Loss = {}
# Batch No: 236 Loss = {}
# Batch No: 237 Loss = {}
# Batch No: 238 Loss = {}
# Batch No: 239 Loss = {}
# Batch No: 240 Loss = {}
# Batch No: 241 Loss = {}
# Batch No: 242 Loss = {}
# Batch No: 243 Loss = {}
# Batch No: 244 Loss = {}
# Batch No: 245 Loss = {}
# Batch No: 246 Loss = {}
# Batch No: 247 Loss = {}
# Batch No: 248 Loss = {}
# Batch No: 249 Loss = {}
# Batch No: 250 Loss = {}
# Batch No: 251 Loss = {}
# Batch No: 252 Loss = {}
# Batch No: 253 Loss = {}
# Batch No: 254 Loss = {}
# Batch No: 255 Loss = {}
# Batch No: 256 Loss = {}
# Batch No: 257 Loss = {}
# Batch No: 258 Loss = {}
# Batch No: 259 Loss = {}
# Batch No: 260 Loss = {}
# Batch No: 261 Loss = {}
# Batch No: 262 Loss = {}
# Batch No: 263 Loss = {}
# Batch No: 264 Loss = {}
# Batch No: 265 Loss = {}
# Batch No: 266 Loss = {}
# Batch No: 267 Loss = {}
# Batch No: 268 Loss = {}
# Batch No: 269 Loss = {}
# Batch No: 270 Loss = {}
# Batch No: 271 Loss = {}
# Batch No: 272 Loss = {}
# Batch No: 273 Loss = {}
# Batch No: 274 Loss = {}
# Batch No: 275 Loss = {}
# Batch No: 276 Loss = {}
# Batch No: 277 Loss = {}
# Batch No: 278 Loss = {}
# Batch No: 279 Loss = {}
# Batch No: 280 Loss = {}
# Batch No: 281 Loss = {}
# Batch No: 282 Loss = {}
# Batch No: 283 Loss = {}
# Batch No: 284 Loss = {}
# Batch No: 285 Loss = {}
# Batch No: 286 Loss = {}
# Batch No: 287 Loss = {}
# Batch No: 288 Loss = {}
# Batch No: 289 Loss = {}
# Batch No: 290 Loss = {}
# Batch No: 291 Loss = {}
# Batch No: 292 Loss = {}
# Batch No: 293 Loss = {}
# Batch No: 294 Loss = {}
# Batch No: 295 Loss = {}
# Batch No: 296 Loss = {}
# Batch No: 297 Loss = {}
# Batch No: 298 Loss = {}
# Batch No: 299 Loss = {}
# Batch No: 300 Loss = {}
# Batch No: 301 Loss = {}
# Batch No: 302 Loss = {}
# Batch No: 303 Loss = {}
# Batch No: 304 Loss = {}
# Batch No: 305 Loss = {}
# Batch No: 306 Loss = {}
# Batch No: 307 Loss = {}
# Batch No: 308 Loss = {}
# Batch No: 309 Loss = {}
# Batch No: 310 Loss = {}
# Batch No: 311 Loss = {}
# Batch No: 312 Loss = {}
# Batch No: 313 Loss = {}
# Batch No: 314 Loss = {}
# Batch No: 315 Loss = {}
# Batch No: 316 Loss = {}
# Batch No: 317 Loss = {}
# Batch No: 318 Loss = {}
# Batch No: 319 Loss = {}
# Batch No: 320 Loss = {}
# Batch No: 321 Loss = {}
# Batch No: 322 Loss = {}
# Batch No: 323 Loss = {}
# Batch No: 324 Loss = {}
# Batch No: 325 Loss = {}
# Batch No: 326 Loss = {}
# Batch No: 327 Loss = {}
# Batch No: 328 Loss = {}
# Batch No: 329 Loss = {}
# Batch No: 330 Loss = {}
# Batch No: 331 Loss = {}
# Batch No: 332 Loss = {}
# Batch No: 333 Loss = {}
# Batch No: 334 Loss = {}
# Batch No: 335 Loss = {}
# Batch No: 336 Loss = {}
# Batch No: 337 Loss = {}
# Batch No: 338 Loss = {}
# Batch No: 339 Loss = {}
# Batch No: 340 Loss = {}
# Batch No: 341 Loss = {}
# Batch No: 342 Loss = {}
# Batch No: 343 Loss = {}
# Batch No: 344 Loss = {}
# Batch No: 345 Loss = {}
# Batch No: 346 Loss = {}
# Batch No: 347 Loss = {}
# Batch No: 348 Loss = {}
# Batch No: 349 Loss = {}
# Batch No: 350 Loss = {}
# Batch No: 351 Loss = {}
# Batch No: 352 Loss = {}
# Batch No: 353 Loss = {}
# Batch No: 354 Loss = {}
# Batch No: 355 Loss = {}
# Batch No: 356 Loss = {}
# Batch No: 357 Loss = {}
# Batch No: 358 Loss = {}
# Batch No: 359 Loss = {}
# Batch No: 360 Loss = {}
# Batch No: 361 Loss = {}
# Batch No: 362 Loss = {}
# Batch No: 363 Loss = {}
# Batch No: 364 Loss = {}
# Batch No: 365 Loss = {}
# Batch No: 366 Loss = {}
# Batch No: 367 Loss = {}
# Batch No: 368 Loss = {}
# Batch No: 369 Loss = {}
# Batch No: 370 Loss = {}
# Batch No: 371 Loss = {}
# Batch No: 372 Loss = {}
# Batch No: 373 Loss = {}
# Batch No: 374 Loss = {}
# Batch No: 375 Loss = {}
# Batch No: 376 Loss = {}
# Batch No: 377 Loss = {}
# Batch No: 378 Loss = {}
# Batch No: 379 Loss = {}
# Batch No: 380 Loss = {}
# Batch No: 381 Loss = {}
# Batch No: 382 Loss = {}
# Batch No: 383 Loss = {}
# Batch No: 384 Loss = {}
# Batch No: 385 Loss = {}
# Batch No: 386 Loss = {}
# Batch No: 387 Loss = {}
# Batch No: 388 Loss = {}
# Batch No: 389 Loss = {}
# Batch No: 390 Loss = {}
# Batch No: 391 Loss = {}
# Batch No: 392 Loss = {}
# Batch No: 393 Loss = {}
# Batch No: 394 Loss = {}
# Batch No: 395 Loss = {}
# Batch No: 396 Loss = {}
# Batch No: 397 Loss = {}
# Batch No: 398 Loss = {}
# Batch No: 399 Loss = {}
# Batch No: 400 Loss = {}
# Batch No: 401 Loss = {}
# Batch No: 402 Loss = {}
# Batch No: 403 Loss = {}
# Batch No: 404 Loss = {}
# Batch No: 405 Loss = {}
# Batch No: 406 Loss = {}
# Batch No: 407 Loss = {}
# Batch No: 408 Loss = {}
# Batch No: 409 Loss = {}
# Batch No: 410 Loss = {}
# Batch No: 411 Loss = {}
# Batch No: 412 Loss = {}
# Batch No: 413 Loss = {}
# Batch No: 414 Loss = {}
# Batch No: 415 Loss = {}
# Batch No: 416 Loss = {}
# Batch No: 417 Loss = {}
# Batch No: 418 Loss = {}
# Batch No: 419 Loss = {}
# Batch No: 420 Loss = {}
# Batch No: 421 Loss = {}
# Batch No: 422 Loss = {}
# Batch No: 423 Loss = {}
# Batch No: 424 Loss = {}
# Batch No: 425 Loss = {}
# Batch No: 426 Loss = {}
# Batch No: 427 Loss = {}
# Batch No: 428 Loss = {}
# Batch No: 429 Loss = {}
# Batch No: 430 Loss = {}
# Batch No: 431 Loss = {}
# Batch No: 432 Loss = {}
# Batch No: 433 Loss = {}
# Batch No: 434 Loss = {}
# Batch No: 435 Loss = {}
# Batch No: 436 Loss = {}
# Batch No: 437 Loss = {}
# Batch No: 438 Loss = {}
# Batch No: 439 Loss = {}
# Batch No: 440 Loss = {}
# Batch No: 441 Loss = {}
# Batch No: 442 Loss = {}
# Batch No: 443 Loss = {}
# Batch No: 444 Loss = {}
# Batch No: 445 Loss = {}
# Batch No: 446 Loss = {}
# Batch No: 447 Loss = {}
# Batch No: 448 Loss = {}
# Batch No: 449 Loss = {}
# Batch No: 450 Loss = {}
# Batch No: 451 Loss = {}
# Batch No: 452 Loss = {}
# Batch No: 453 Loss = {}
# Batch No: 454 Loss = {}
# Batch No: 455 Loss = {}
# Batch No: 456 Loss = {}
# Batch No: 457 Loss = {}
# Batch No: 458 Loss = {}
# Batch No: 459 Loss = {}
# Batch No: 460 Loss = {}
# Batch No: 461 Loss = {}
# Batch No: 462 Loss = {}
# Batch No: 463 Loss = {}
# Batch No: 464 Loss = {}
# Batch No: 465 Loss = {}
# Batch No: 466 Loss = {}
# Batch No: 467 Loss = {}
# Batch No: 468 Loss = {}
# Batch No: 469 Loss = {}
# Batch No: 470 Loss = {}
# Batch No: 471 Loss = {}
# Batch No: 472 Loss = {}
# Batch No: 473 Loss = {}
# Batch No: 474 Loss = {}
# Batch No: 475 Loss = {}
# Batch No: 476 Loss = {}
# Batch No: 477 Loss = {}
# Batch No: 478 Loss = {}
# Batch No: 479 Loss = {}
# Batch No: 480 Loss = {}
# Batch No: 481 Loss = {}
# Batch No: 482 Loss = {}
# Batch No: 483 Loss = {}
# Batch No: 484 Loss = {}
# Batch No: 485 Loss = {}
# Batch No: 486 Loss = {}
# Batch No: 487 Loss = {}
# Batch No: 488 Loss = {}
# Batch No: 489 Loss = {}
# Batch No: 490 Loss = {}
# Batch No: 491 Loss = {}
# Batch No: 492 Loss = {}
# Batch No: 493 Loss = {}
# Batch No: 494 Loss = {}
# Batch No: 495 Loss = {}
# Batch No: 496 Loss = {}
# Batch No: 497 Loss = {}
# Batch No: 498 Loss = {}
# Batch No: 499 Loss = {}
# Batch No: 500 Loss = {}
# Batch No: 501 Loss = {}
# Batch No: 502 Loss = {}
# Batch No: 503 Loss = {}
# Batch No: 504 Loss = {}
# Batch No: 505 Loss = {}
# Batch No: 506 Loss = {}
# Batch No: 507 Loss = {}
# Batch No: 508 Loss = {}
# Batch No: 509 Loss = {}
# Batch No: 510 Loss = {}
# Batch No: 511 Loss = {}
# Batch No: 512 Loss = {}
# Batch No: 513 Loss = {}
# Batch No: 514 Loss = {}
# Batch No: 515 Loss = {}
# Batch No: 516 Loss = {}
# Batch No: 517 Loss = {}
# Batch No: 518 Loss = {}
# Batch No: 519 Loss = {}
# Batch No: 520 Loss = {}
# Batch No: 521 Loss = {}
# Batch No: 522 Loss = {}
# Batch No: 523 Loss = {}
# Batch No: 524 Loss = {}
# Batch No: 525 Loss = {}
# Batch No: 526 Loss = {}
# Batch No: 527 Loss = {}
# Batch No: 528 Loss = {}
# Batch No: 529 Loss = {}
# Batch No: 530 Loss = {}
# Batch No: 531 Loss = {}
# Batch No: 532 Loss = {}
# Batch No: 533 Loss = {}
# Batch No: 534 Loss = {}
# Batch No: 535 Loss = {}
# Batch No: 536 Loss = {}
# Batch No: 537 Loss = {}
# Batch No: 538 Loss = {}
# Batch No: 539 Loss = {}
# Batch No: 540 Loss = {}
# Batch No: 541 Loss = {}
# Batch No: 542 Loss = {}
# Batch No: 543 Loss = {}
# Batch No: 544 Loss = {}
# Batch No: 545 Loss = {}
# Batch No: 546 Loss = {}
# Batch No: 547 Loss = {}
# Batch No: 548 Loss = {}
# Batch No: 549 Loss = {}
# Batch No: 550 Loss = {}
# Batch No: 551 Loss = {}
# Batch No: 552 Loss = {}
# Batch No: 553 Loss = {}
# Batch No: 554 Loss = {}
# Batch No: 555 Loss = {}
# Batch No: 556 Loss = {}
# Batch No: 557 Loss = {}
# Batch No: 558 Loss = {}
# Batch No: 559 Loss = {}
# Batch No: 560 Loss = {}
# Batch No: 561 Loss = {}
# Batch No: 562 Loss = {}
# Batch No: 563 Loss = {}
# Batch No: 564 Loss = {}
# Batch No: 565 Loss = {}
# Batch No: 566 Loss = {}
# Batch No: 567 Loss = {}
# Batch No: 568 Loss = {}
# Batch No: 569 Loss = {}
# Batch No: 570 Loss = {}
# Batch No: 571 Loss = {}
# Batch No: 572 Loss = {}
# Batch No: 573 Loss = {}
# Batch No: 574 Loss = {}
# Batch No: 575 Loss = {}
# Batch No: 576 Loss = {}
# Batch No: 577 Loss = {}
# Batch No: 578 Loss = {}
# Batch No: 579 Loss = {}
# Batch No: 580 Loss = {}
# Batch No: 581 Loss = {}
# Batch No: 582 Loss = {}
# Batch No: 583 Loss = {}
# Batch No: 584 Loss = {}
# Batch No: 585 Loss = {}
# Batch No: 586 Loss = {}
# Batch No: 587 Loss = {}
# Batch No: 588 Loss = {}
# Batch No: 589 Loss = {}
# Batch No: 590 Loss = {}
# Batch No: 591 Loss = {}
# Batch No: 592 Loss = {}
# Batch No: 593 Loss = {}
# Batch No: 594 Loss = {}
# Batch No: 595 Loss = {}
# Batch No: 596 Loss = {}
# Batch No: 597 Loss = {}
# Batch No: 598 Loss = {}
# Batch No: 599 Loss = {}
# Batch No: 600 Loss = {}
# Batch No: 601 Loss = {}
# Batch No: 602 Loss = {}
# Batch No: 603 Loss = {}
# Batch No: 604 Loss = {}
# Batch No: 605 Loss = {}
# Batch No: 606 Loss = {}
# Batch No: 607 Loss = {}
# Batch No: 608 Loss = {}
# Batch No: 609 Loss = {}
# Batch No: 610 Loss = {}
# Batch No: 611 Loss = {}
# Batch No: 612 Loss = {}
# Batch No: 613 Loss = {}
# Batch No: 614 Loss = {}
# Batch No: 615 Loss = {}
# Batch No: 616 Loss = {}
# Batch No: 617 Loss = {}
# Batch No: 618 Loss = {}
# Batch No: 619 Loss = {}
# Batch No: 620 Loss = {}
# Batch No: 621 Loss = {}
# Batch No: 622 Loss = {}
# Batch No: 623 Loss = {}
# Batch No: 624 Loss = {}
# Batch No: 625 Loss = {}
# Batch No: 626 Loss = {}
# Batch No: 627 Loss = {}
# Batch No: 628 Loss = {}
# Batch No: 629 Loss = {}
# Batch No: 630 Loss = {}
# Batch No: 631 Loss = {}
# Batch No: 632 Loss = {}
# Batch No: 633 Loss = {}
# Batch No: 634 Loss = {}
# Batch No: 635 Loss = {}
# Batch No: 636 Loss = {}
# Batch No: 637 Loss = {}
# Batch No: 638 Loss = {}
# Batch No: 639 Loss = {}
# Batch No: 640 Loss = {}
# Batch No: 641 Loss = {}
# Batch No: 642 Loss = {}
# Batch No: 643 Loss = {}
# Batch No: 644 Loss = {}
# Batch No: 645 Loss = {}
# Batch No: 646 Loss = {}
# Batch No: 647 Loss = {}
# Batch No: 648 Loss = {}
# Batch No: 649 Loss = {}
# Batch No: 650 Loss = {}
# Batch No: 651 Loss = {}
# Batch No: 652 Loss = {}
# Batch No: 653 Loss = {}
# Batch No: 654 Loss = {}
# Batch No: 655 Loss = {}
# Batch No: 656 Loss = {}
# Batch No: 657 Loss = {}
# Batch No: 658 Loss = {}
# Batch No: 659 Loss = {}
# Batch No: 660 Loss = {}
# Batch No: 661 Loss = {}
# Batch No: 662 Loss = {}
# Batch No: 663 Loss = {}
# Batch No: 664 Loss = {}
# Batch No: 665 Loss = {}
# Batch No: 666 Loss = {}
# Batch No: 667 Loss = {}
# Batch No: 668 Loss = {}
# Batch No: 669 Loss = {}
# Batch No: 670 Loss = {}
# Batch No: 671 Loss = {}
# Batch No: 672 Loss = {}
# Batch No: 673 Loss = {}
# Batch No: 674 Loss = {}
# Batch No: 675 Loss = {}
# Batch No: 676 Loss = {}
# Batch No: 677 Loss = {}
# Batch No: 678 Loss = {}
# Batch No: 679 Loss = {}
# Batch No: 680 Loss = {}
# Batch No: 681 Loss = {}
# Batch No: 682 Loss = {}
# Batch No: 683 Loss = {}
# Batch No: 684 Loss = {}
# Batch No: 685 Loss = {}
# Batch No: 686 Loss = {}
# Batch No: 687 Loss = {}
# Batch No: 688 Loss = {}
# Batch No: 689 Loss = {}
# Batch No: 690 Loss = {}
# Batch No: 691 Loss = {}
# Batch No: 692 Loss = {}
# Batch No: 693 Loss = {}
# Batch No: 694 Loss = {}
# Batch No: 695 Loss = {}
# Batch No: 696 Loss = {}
# Batch No: 697 Loss = {}
# Batch No: 698 Loss = {}
# Batch No: 699 Loss = {}
# Batch No: 700 Loss = {}
# Batch No: 701 Loss = {}
# Batch No: 702 Loss = {}
# Batch No: 703 Loss = {}
# Batch No: 704 Loss = {}
# Batch No: 705 Loss = {}
# Batch No: 706 Loss = {}
# Batch No: 707 Loss = {}
# Batch No: 708 Loss = {}
# Batch No: 709 Loss = {}
# Batch No: 710 Loss = {}
# Batch No: 711 Loss = {}
# Batch No: 712 Loss = {}
# Batch No: 713 Loss = {}
# Batch No: 714 Loss = {}
# Batch No: 715 Loss = {}
# Batch No: 716 Loss = {}
# Batch No: 717 Loss = {}
# Batch No: 718 Loss = {}
# Batch No: 719 Loss = {}
# Batch No: 720 Loss = {}
# Batch No: 721 Loss = {}
# Batch No: 722 Loss = {}
# Batch No: 723 Loss = {}
# Batch No: 724 Loss = {}
# Batch No: 725 Loss = {}
# Batch No: 726 Loss = {}
# Batch No: 727 Loss = {}
# Batch No: 728 Loss = {}
# Batch No: 729 Loss = {}
# Batch No: 730 Loss = {}
# Batch No: 731 Loss = {}
# Batch No: 732 Loss = {}
# Batch No: 733 Loss = {}
# Batch No: 734 Loss = {}
# Batch No: 735 Loss = {}
# Batch No: 736 Loss = {}
# Batch No: 737 Loss = {}
# Batch No: 738 Loss = {}
# Batch No: 739 Loss = {}
# Batch No: 740 Loss = {}
# Batch No: 741 Loss = {}
# Batch No: 742 Loss = {}
# Batch No: 743 Loss = {}
# Batch No: 744 Loss = {}
# Batch No: 745 Loss = {}
# Batch No: 746 Loss = {}
# Batch No: 747 Loss = {}
# Batch No: 748 Loss = {}
# Batch No: 749 Loss = {}
# Batch No: 750 Loss = {}
# Batch No: 751 Loss = {}
# Batch No: 752 Loss = {}
# Batch No: 753 Loss = {}
# Batch No: 754 Loss = {}
# Batch No: 755 Loss = {}
# Batch No: 756 Loss = {}
# Batch No: 757 Loss = {}
# Batch No: 758 Loss = {}
# Batch No: 759 Loss = {}
# Batch No: 760 Loss = {}
# Batch No: 761 Loss = {}
# Batch No: 762 Loss = {}
# Batch No: 763 Loss = {}
# Batch No: 764 Loss = {}
# Batch No: 765 Loss = {}
# Batch No: 766 Loss = {}
# Batch No: 767 Loss = {}
# Batch No: 768 Loss = {}
# Batch No: 769 Loss = {}
# Batch No: 770 Loss = {}
# Batch No: 771 Loss = {}
# Batch No: 772 Loss = {}
# Batch No: 773 Loss = {}
# Batch No: 774 Loss = {}
# Batch No: 775 Loss = {}
# Batch No: 776 Loss = {}
# Batch No: 777 Loss = {}
# Batch No: 778 Loss = {}
# Batch No: 779 Loss = {}
# Batch No: 780 Loss = {}
# Batch No: 781 Loss = {}
# Batch No: 782 Loss = {}
# Batch No: 783 Loss = {}
# Batch No: 784 Loss = {}
# Batch No: 785 Loss = {}
# Batch No: 786 Loss = {}
# Batch No: 787 Loss = {}
# Batch No: 788 Loss = {}
# Batch No: 789 Loss = {}
# Batch No: 790 Loss = {}
# Batch No: 791 Loss = {}
# Batch No: 792 Loss = {}
# Batch No: 793 Loss = {}
# Batch No: 794 Loss = {}
# Batch No: 795 Loss = {}
# Batch No: 796 Loss = {}
# Batch No: 797 Loss = {}
# Batch No: 798 Loss = {}
# Batch No: 799 Loss = {}
# Batch No: 800 Loss = {}
# Batch No: 801 Loss = {}
# Batch No: 802 Loss = {}
# Batch No: 803 Loss = {}
# Batch No: 804 Loss = {}
# Batch No: 805 Loss = {}
# Batch No: 806 Loss = {}
# Batch No: 807 Loss = {}
# Batch No: 808 Loss = {}
# Batch No: 809 Loss = {}
# Batch No: 810 Loss = {}
# Batch No: 811 Loss = {}
# Batch No: 812 Loss = {}
# Batch No: 813 Loss = {}
# Batch No: 814 Loss = {}
# Batch No: 815 Loss = {}
# Batch No: 816 Loss = {}
# Batch No: 817 Loss = {}
# Batch No: 818 Loss = {}
# Batch No: 819 Loss = {}
# Batch No: 820 Loss = {}
# Batch No: 821 Loss = {}
# Batch No: 822 Loss = {}
# Batch No: 823 Loss = {}
# Batch No: 824 Loss = {}
# Batch No: 825 Loss = {}
# Batch No: 826 Loss = {}
# Batch No: 827 Loss = {}
# Batch No: 828 Loss = {}
# Batch No: 829 Loss = {}
# Batch No: 830 Loss = {}
# Batch No: 831 Loss = {}
# Batch No: 832 Loss = {}
# Batch No: 833 Loss = {}
# Batch No: 834 Loss = {}
# Batch No: 835 Loss = {}
# Batch No: 836 Loss = {}
# Batch No: 837 Loss = {}
# Batch No: 838 Loss = {}
# Batch No: 839 Loss = {}
# Batch No: 840 Loss = {}
# Batch No: 841 Loss = {}
# Batch No: 842 Loss = {}
# Batch No: 843 Loss = {}
# Batch No: 844 Loss = {}
# Batch No: 845 Loss = {}
# Batch No: 846 Loss = {}
# Batch No: 847 Loss = {}
# Batch No: 848 Loss = {}
# Batch No: 849 Loss = {}
# Batch No: 850 Loss = {}
# Batch No: 851 Loss = {}
# Batch No: 852 Loss = {}
# Batch No: 853 Loss = {}
# Batch No: 854 Loss = {}
# Batch No: 855 Loss = {}
# Batch No: 856 Loss = {}
# Batch No: 857 Loss = {}
# Batch No: 858 Loss = {}
# Batch No: 859 Loss = {}
# Batch No: 860 Loss = {}
# Batch No: 861 Loss = {}
# Batch No: 862 Loss = {}
# Batch No: 863 Loss = {}
# Batch No: 864 Loss = {}
# Batch No: 865 Loss = {}
# Batch No: 866 Loss = {}
# Batch No: 867 Loss = {}
# Batch No: 868 Loss = {}
# Batch No: 869 Loss = {}
# Batch No: 870 Loss = {}
# Batch No: 871 Loss = {}
# Batch No: 872 Loss = {}
# Batch No: 873 Loss = {}
# Batch No: 874 Loss = {}
# Batch No: 875 Loss = {}
# Batch No: 876 Loss = {}
# Batch No: 877 Loss = {}
# Batch No: 878 Loss = {}
# Batch No: 879 Loss = {}
# Batch No: 880 Loss = {}
# Batch No: 881 Loss = {}
# Batch No: 882 Loss = {}
# Batch No: 883 Loss = {}
# Batch No: 884 Loss = {}
# Batch No: 885 Loss = {}
# Batch No: 886 Loss = {}
# Batch No: 887 Loss = {}
# Batch No: 888 Loss = {}
# Batch No: 889 Loss = {}
# Batch No: 890 Loss = {}
# Batch No: 891 Loss = {}
# Batch No: 892 Loss = {}
# Batch No: 893 Loss = {}
# Batch No: 894 Loss = {}
# Batch No: 895 Loss = {}
# Batch No: 896 Loss = {}
# Batch No: 897 Loss = {}
# Batch No: 898 Loss = {}
# Batch No: 899 Loss = {}
# Batch No: 900 Loss = {}
# Batch No: 901 Loss = {}
# Batch No: 902 Loss = {}
# Batch No: 903 Loss = {}
# Batch No: 904 Loss = {}
# Batch No: 905 Loss = {}
# Batch No: 906 Loss = {}
# Batch No: 907 Loss = {}
# Batch No: 908 Loss = {}
# Batch No: 909 Loss = {}
# Batch No: 910 Loss = {}
# Batch No: 911 Loss = {}
# Batch No: 912 Loss = {}
# Batch No: 913 Loss = {}
# Batch No: 914 Loss = {}
# Batch No: 915 Loss = {}
# Batch No: 916 Loss = {}
# Batch No: 917 Loss = {}
# Batch No: 918 Loss = {}
# Batch No: 919 Loss = {}
# Batch No: 920 Loss = {}
# Batch No: 921 Loss = {}
# Batch No: 922 Loss = {}
# Batch No: 923 Loss = {}
# Batch No: 924 Loss = {}
# Batch No: 925 Loss = {}
# Batch No: 926 Loss = {}
# Batch No: 927 Loss = {}
# Batch No: 928 Loss = {}
# Batch No: 929 Loss = {}
# Batch No: 930 Loss = {}
# Batch No: 931 Loss = {}
# Batch No: 932 Loss = {}
# Batch No: 933 Loss = {}
# Batch No: 934 Loss = {}
# Batch No: 935 Loss = {}
# Batch No: 936 Loss = {}
# Batch No: 937 Loss = {}
# Batch No: 938 Loss = {}
# Batch No: 939 Loss = {}
# Batch No: 940 Loss = {}
# Batch No: 941 Loss = {}
# Batch No: 942 Loss = {}
# Batch No: 943 Loss = {}
# Batch No: 944 Loss = {}
# Batch No: 945 Loss = {}
# Batch No: 946 Loss = {}
# Batch No: 947 Loss = {}
# Batch No: 948 Loss = {}
# Batch No: 949 Loss = {}
# Batch No: 950 Loss = {}
# Batch No: 951 Loss = {}
# Batch No: 952 Loss = {}
# Batch No: 953 Loss = {}
# Batch No: 954 Loss = {}
# Batch No: 955 Loss = {}
# Batch No: 956 Loss = {}
# Batch No: 957 Loss = {}
# Batch No: 958 Loss = {}
# Batch No: 959 Loss = {}
# Batch No: 960 Loss = {}
# Batch No: 961 Loss = {}
# Batch No: 962 Loss = {}
# Batch No: 963 Loss = {}
# Batch No: 964 Loss = {}
# Batch No: 965 Loss = {}
# Batch No: 966 Loss = {}
# Batch No: 967 Loss = {}
# Batch No: 968 Loss = {}
# Batch No: 969 Loss = {}
# Batch No: 970 Loss = {}
# Batch No: 971 Loss = {}
# Batch No: 972 Loss = {}
# Batch No: 973 Loss = {}
# Batch No: 974 Loss = {}
# Batch No: 975 Loss = {}
# Batch No: 976 Loss = {}
# Batch No: 977 Loss = {}
# Batch No: 978 Loss = {}
# Batch No: 979 Loss = {}
# Batch No: 980 Loss = {}
# Batch No: 981 Loss = {}
# Batch No: 982 Loss = {}
# Batch No: 983 Loss = {}
# Batch No: 984 Loss = {}
# Batch No: 985 Loss = {}
# Batch No: 986 Loss = {}
# Batch No: 987 Loss = {}
# Batch No: 988 Loss = {}
# Batch No: 989 Loss = {}
# Batch No: 990 Loss = {}
# Batch No: 991 Loss = {}
# Batch No: 992 Loss = {}
# Batch No: 993 Loss = {}
# Batch No: 994 Loss = {}
# Batch No: 995 Loss = {}
# Batch No: 996 Loss = {}
# Batch No: 997 Loss = {}
# Batch No: 998 Loss = {}
# Batch No: 999 Loss = {}
# Batch No: 1000 Loss = {}
# Batch No: 1001 Loss = {}
# Batch No: 1002 Loss = {}
# Batch No: 1003 Loss = {}
# Batch No: 1004 Loss = {}
# Batch No: 1005 Loss = {}
# Batch No: 1006 Loss = {}
# Batch No: 1007 Loss = {}
# Batch No: 1008 Loss = {}
# Batch No: 1009 Loss = {}
# Batch No: 1010 Loss = {}
# Batch No: 1011 Loss = {}
# Batch No: 1012 Loss = {}
# Batch No: 1013 Loss = {}
# Batch No: 1014 Loss = {}
# Batch No: 1015 Loss = {}
# Batch No: 1016 Loss = {}
# Batch No: 1017 Loss = {}
# Batch No: 1018 Loss = {}
# Batch No: 1019 Loss = {}
# Batch No: 1020 Loss = {}
# Batch No: 1021 Loss = {}
# Batch No: 1022 Loss = {}
# Batch No: 1023 Loss = {}
# Batch No: 1024 Loss = {}
# Batch No: 1025 Loss = {}
# Batch No: 1026 Loss = {}
# Batch No: 1027 Loss = {}
# Batch No: 1028 Loss = {}
# Batch No: 1029 Loss = {}
# Batch No: 1030 Loss = {}
# Batch No: 1031 Loss = {}
# Batch No: 1032 Loss = {}
# Batch No: 1033 Loss = {}
# Batch No: 1034 Loss = {}
# Batch No: 1035 Loss = {}
# Batch No: 1036 Loss = {}
# Batch No: 1037 Loss = {}
# Batch No: 1038 Loss = {}
# Batch No: 1039 Loss = {}
# Batch No: 1040 Loss = {}
# Batch No: 1041 Loss = {}
# Batch No: 1042 Loss = {}
# Batch No: 1043 Loss = {}
# Batch No: 1044 Loss = {}
# Batch No: 1045 Loss = {}
# Batch No: 1046 Loss = {}
# Batch No: 1047 Loss = {}
# Batch No: 1048 Loss = {}
# Batch No: 1049 Loss = {}
# Batch No: 1050 Loss = {}
# Batch No: 1051 Loss = {}
# Batch No: 1052 Loss = {}
# Batch No: 1053 Loss = {}
# Batch No: 1054 Loss = {}
# Batch No: 1055 Loss = {}
# Batch No: 1056 Loss = {}
# Batch No: 1057 Loss = {}
# Batch No: 1058 Loss = {}
# Batch No: 1059 Loss = {}
# Batch No: 1060 Loss = {}
# Batch No: 1061 Loss = {}
# Batch No: 1062 Loss = {}
# Batch No: 1063 Loss = {}
# Batch No: 1064 Loss = {}
# Batch No: 1065 Loss = {}
# Batch No: 1066 Loss = {}
# Batch No: 1067 Loss = {}
# Batch No: 1068 Loss = {}
# Batch No: 1069 Loss = {}
# Batch No: 1070 Loss = {}
# Batch No: 1071 Loss = {}
# Batch No: 1072 Loss = {}
# Batch No: 1073 Loss = {}
# Batch No: 1074 Loss = {}
# Batch No: 1075 Loss = {}
# Batch No: 1076 Loss = {}
# Batch No: 1077 Loss = {}
# Batch No: 1078 Loss = {}
# Batch No: 1079 Loss = {}
# Batch No: 1080 Loss = {}
# Batch No: 1081 Loss = {}
# Batch No: 1082 Loss = {}
# Batch No: 1083 Loss = {}
# Batch No: 1084 Loss = {}
# Batch No: 1085 Loss = {}
# Batch No: 1086 Loss = {}
# Batch No: 1087 Loss = {}
# Batch No: 1088 Loss = {}
# Batch No: 1089 Loss = {}
# Batch No: 1090 Loss = {}
# Batch No: 1091 Loss = {}
# Batch No: 1092 Loss = {}
# Batch No: 1093 Loss = {}
# Batch No: 1094 Loss = {}
# Batch No: 1095 Loss = {}
# Batch No: 1096 Loss = {}
# Batch No: 1097 Loss = {}
# Batch No: 1098 Loss = {}
# Batch No: 1099 Loss = {}
# Batch No: 1100 Loss = {}
# Batch No: 1101 Loss = {}
# Batch No: 1102 Loss = {}
# Batch No: 1103 Loss = {}
# Batch No: 1104 Loss = {}
# Batch No: 1105 Loss = {}
# Batch No: 1106 Loss = {}
# Batch No: 1107 Loss = {}
# Batch No: 1108 Loss = {}
# Batch No: 1109 Loss = {}
# Batch No: 1110 Loss = {}
# Batch No: 1111 Loss = {}
# Batch No: 1112 Loss = {}
# Batch No: 1113 Loss = {}
# Batch No: 1114 Loss = {}
# Batch No: 1115 Loss = {}
# Batch No: 1116 Loss = {}
# Batch No: 1117 Loss = {}
# Batch No: 1118 Loss = {}
# Batch No: 1119 Loss = {}
# Batch No: 1120 Loss = {}
# Batch No: 1121 Loss = {}
# Batch No: 1122 Loss = {}
# Batch No: 1123 Loss = {}
# Batch No: 1124 Loss = {}
# Batch No: 1125 Loss = {}
# Batch No: 1126 Loss = {}
# Batch No: 1127 Loss = {}
# Batch No: 1128 Loss = {}
# Batch No: 1129 Loss = {}
# Batch No: 1130 Loss = {}
# Batch No: 1131 Loss = {}
# Batch No: 1132 Loss = {}
# Batch No: 1133 Loss = {}
# Batch No: 1134 Loss = {}
# Batch No: 1135 Loss = {}
# Batch No: 1136 Loss = {}
# Batch No: 1137 Loss = {}
# Batch No: 1138 Loss = {}
# Batch No: 1139 Loss = {}
# Batch No: 1140 Loss = {}
# Batch No: 1141 Loss = {}
# Batch No: 1142 Loss = {}
# Batch No: 1143 Loss = {}
# Batch No: 1144 Loss = {}
# Batch No: 1145 Loss = {}
# Batch No: 1146 Loss = {}
# Batch No: 1147 Loss = {}
# Batch No: 1148 Loss = {}
# Batch No: 1149 Loss = {}
# Batch No: 1150 Loss = {}
# Batch No: 1151 Loss = {}
# Batch No: 1152 Loss = {}
# Batch No: 1153 Loss = {}
# Batch No: 1154 Loss = {}
# Batch No: 1155 Loss = {}
# Batch No: 1156 Loss = {}
# Batch No: 1157 Loss = {}
# Batch No: 1158 Loss = {}
# Batch No: 1159 Loss = {}
# Batch No: 1160 Loss = {}
# Batch No: 1161 Loss = {}
# Batch No: 1162 Loss = {}
# Batch No: 1163 Loss = {}
# Batch No: 1164 Loss = {}
# Batch No: 1165 Loss = {}
# Batch No: 1166 Loss = {}
# Batch No: 1167 Loss = {}
# Batch No: 1168 Loss = {}
# Batch No: 1169 Loss = {}
# Batch No: 1170 Loss = {}
# Batch No: 1171 Loss = {}
# Batch No: 1172 Loss = {}
# Batch No: 1173 Loss = {}
# Batch No: 1174 Loss = {}
# Batch No: 1175 Loss = {}
# Batch No: 1176 Loss = {}
# Batch No: 1177 Loss = {}
# Batch No: 1178 Loss = {}
# Batch No: 1179 Loss = {}
# Batch No: 1180 Loss = {}
# Batch No: 1181 Loss = {}
# Batch No: 1182 Loss = {}
# Batch No: 1183 Loss = {}
# Batch No: 1184 Loss = {}
# Batch No: 1185 Loss = {}
# Batch No: 1186 Loss = {}
# Batch No: 1187 Loss = {}
# Batch No: 1188 Loss = {}
# Batch No: 1189 Loss = {}
# Batch No: 1190 Loss = {}
# Batch No: 1191 Loss = {}
# Batch No: 1192 Loss = {}
# Batch No: 1193 Loss = {}
# Batch No: 1194 Loss = {}
# Batch No: 1195 Loss = {}
# Batch No: 1196 Loss = {}
# Batch No: 1197 Loss = {}
# Batch No: 1198 Loss = {}
# Batch No: 1199 Loss = {}
# Batch No: 1200 Loss = {}
# Batch No: 1201 Loss = {}
# Batch No: 1202 Loss = {}
# Batch No: 1203 Loss = {}
# Batch No: 1204 Loss = {}
# Batch No: 1205 Loss = {}
# Batch No: 1206 Loss = {}
# Batch No: 1207 Loss = {}
# Batch No: 1208 Loss = {}
# Batch No: 1209 Loss = {}
# Batch No: 1210 Loss = {}
# Batch No: 1211 Loss = {}
# Batch No: 1212 Loss = {}
# Batch No: 1213 Loss = {}
# Batch No: 1214 Loss = {}
# Batch No: 1215 Loss = {}
# Batch No: 1216 Loss = {}
# Batch No: 1217 Loss = {}
# Batch No: 1218 Loss = {}
# Batch No: 1219 Loss = {}
# Batch No: 1220 Loss = {}
# Batch No: 1221 Loss = {}
# Batch No: 1222 Loss = {}
# Batch No: 1223 Loss = {}
# Batch No: 1224 Loss = {}
# Batch No: 1225 Loss = {}
# Batch No: 1226 Loss = {}
# Batch No: 1227 Loss = {}
# Batch No: 1228 Loss = {}
# Batch No: 1229 Loss = {}
# Batch No: 1230 Loss = {}
# Batch No: 1231 Loss = {}
# Batch No: 1232 Loss = {}
# Batch No: 1233 Loss = {}
# Batch No: 1234 Loss = {}
# Batch No: 1235 Loss = {}
# Batch No: 1236 Loss = {}
# Batch No: 1237 Loss = {}
# Batch No: 1238 Loss = {}
# Batch No: 1239 Loss = {}
# Batch No: 1240 Loss = {}
# Batch No: 1241 Loss = {}
# Batch No: 1242 Loss = {}
# Batch No: 1243 Loss = {}
# Batch No: 1244 Loss = {}
# Batch No: 1245 Loss = {}
# Batch No: 1246 Loss = {}
# Batch No: 1247 Loss = {}
# Batch No: 1248 Loss = {}
# Batch No: 1249 Loss = {}
# Batch No: 1250 Loss = {}
# Batch No: 1251 Loss = {}
# Batch No: 1252 Loss = {}
# Batch No: 1253 Loss = {}
# Batch No: 1254 Loss = {}
# Batch No: 1255 Loss = {}
# Batch No: 1256 Loss = {}
# Batch No: 1257 Loss = {}
# Batch No: 1258 Loss = {}
# Batch No: 1259 Loss = {}
# Batch No: 1260 Loss = {}
# Batch No: 1261 Loss = {}
# Batch No: 1262 Loss = {}
# Batch No: 1263 Loss = {}
# Batch No: 1264 Loss = {}
# Batch No: 1265 Loss = {}
# Batch No: 1266 Loss = {}
# Batch No: 1267 Loss = {}
# Batch No: 1268 Loss = {}
# Batch No: 1269 Loss = {}
# Batch No: 1270 Loss = {}
# Batch No: 1271 Loss = {}
# Batch No: 1272 Loss = {}
# Batch No: 1273 Loss = {}
# Batch No: 1274 Loss = {}
# Batch No: 1275 Loss = {}
# Batch No: 1276 Loss = {}
# Batch No: 1277 Loss = {}
# Batch No: 1278 Loss = {}
# Batch No: 1279 Loss = {}
# Batch No: 1280 Loss = {}
# Batch No: 1281 Loss = {}
# Batch No: 1282 Loss = {}
# Batch No: 1283 Loss = {}
# Batch No: 1284 Loss = {}
# Batch No: 1285 Loss = {}
# Batch No: 1286 Loss = {}
# Batch No: 1287 Loss = {}
# Batch No: 1288 Loss = {}
# Batch No: 1289 Loss = {}
# Batch No: 1290 Loss = {}
# Batch No: 1291 Loss = {}
# Batch No: 1292 Loss = {}
# Batch No: 1293 Loss = {}
# Batch No: 1294 Loss = {}
# Batch No: 1295 Loss = {}
# Batch No: 1296 Loss = {}
# Batch No: 1297 Loss = {}
# Batch No: 1298 Loss = {}
# Batch No: 1299 Loss = {}
# Batch No: 1300 Loss = {}
# Batch No: 1301 Loss = {}
# Batch No: 1302 Loss = {}
# Batch No: 1303 Loss = {}
# Batch No: 1304 Loss = {}
# Batch No: 1305 Loss = {}
# Batch No: 1306 Loss = {}
# Batch No: 1307 Loss = {}
# Batch No: 1308 Loss = {}
# Batch No: 1309 Loss = {}
# Batch No: 1310 Loss = {}
# Batch No: 1311 Loss = {}
# Batch No: 1312 Loss = {}
# Batch No: 1313 Loss = {}
# Batch No: 1314 Loss = {}
# Batch No: 1315 Loss = {}
# Batch No: 1316 Loss = {}
# Batch No: 1317 Loss = {}
# Batch No: 1318 Loss = {}
# Batch No: 1319 Loss = {}
# Batch No: 1320 Loss = {}
# Batch No: 1321 Loss = {}
# Batch No: 1322 Loss = {}
# Batch No: 1323 Loss = {}
# Batch No: 1324 Loss = {}
# Batch No: 1325 Loss = {}
# Batch No: 1326 Loss = {}
# Batch No: 1327 Loss = {}
# Batch No: 1328 Loss = {}
# Batch No: 1329 Loss = {}
# Batch No: 1330 Loss = {}
# Batch No: 1331 Loss = {}
# Batch No: 1332 Loss = {}
# Batch No: 1333 Loss = {}
# Batch No: 1334 Loss = {}
# Batch No: 1335 Loss = {}
# Batch No: 1336 Loss = {}
# Batch No: 1337 Loss = {}
# Batch No: 1338 Loss = {}
# Batch No: 1339 Loss = {}
# Batch No: 1340 Loss = {}
# Batch No: 1341 Loss = {}
# Batch No: 1342 Loss = {}
# Batch No: 1343 Loss = {}
# Batch No: 1344 Loss = {}
# Batch No: 1345 Loss = {}
# Batch No: 1346 Loss = {}
# Batch No: 1347 Loss = {}
# Batch No: 1348 Loss = {}
# Batch No: 1349 Loss = {}
# Batch No: 1350 Loss = {}
# Batch No: 1351 Loss = {}
# Batch No: 1352 Loss = {}
# Batch No: 1353 Loss = {}
# Batch No: 1354 Loss = {}
# Batch No: 1355 Loss = {}
# Batch No: 1356 Loss = {}
# Batch No: 1357 Loss = {}
# Batch No: 1358 Loss = {}
# Batch No: 1359 Loss = {}
# Batch No: 1360 Loss = {}
# Batch No: 1361 Loss = {}
# Batch No: 1362 Loss = {}
# Batch No: 1363 Loss = {}
# Batch No: 1364 Loss = {}
# Batch No: 1365 Loss = {}
# Batch No: 1366 Loss = {}
# Batch No: 1367 Loss = {}
# Batch No: 1368 Loss = {}
# Batch No: 1369 Loss = {}
# Batch No: 1370 Loss = {}
# Batch No: 1371 Loss = {}
# Batch No: 1372 Loss = {}
# Batch No: 1373 Loss = {}
# Batch No: 1374 Loss = {}
# Batch No: 1375 Loss = {}
# Batch No: 1376 Loss = {}
# Batch No: 1377 Loss = {}
# Batch No: 1378 Loss = {}
# Batch No: 1379 Loss = {}
# Batch No: 1380 Loss = {}
# Batch No: 1381 Loss = {}
# Batch No: 1382 Loss = {}
# Batch No: 1383 Loss = {}
# Batch No: 1384 Loss = {}
# Batch No: 1385 Loss = {}
# Batch No: 1386 Loss = {}
# Batch No: 1387 Loss = {}
# Batch No: 1388 Loss = {}
# Batch No: 1389 Loss = {}
# Batch No: 1390 Loss = {}
# Batch No: 1391 Loss = {}
# Batch No: 1392 Loss = {}
# Batch No: 1393 Loss = {}
# Batch No: 1394 Loss = {}
# Batch No: 1395 Loss = {}
# Batch No: 1396 Loss = {}
# Batch No: 1397 Loss = {}
# Batch No: 1398 Loss = {}
# Batch No: 1399 Loss = {}
# Batch No: 1400 Loss = {}
# Batch No: 1401 Loss = {}
# Batch No: 1402 Loss = {}
# Batch No: 1403 Loss = {}
# Batch No: 1404 Loss = {}
# Batch No: 1405 Loss = {}
# Batch No: 1406 Loss = {}
# Batch No: 1407 Loss = {}
# Batch No: 1408 Loss = {}
# Batch No: 1409 Loss = {}
# Batch No: 1410 Loss = {}
# Batch No: 1411 Loss = {}
# Batch No: 1412 Loss = {}
# Batch No: 1413 Loss = {}
# Batch No: 1414 Loss = {}
# Batch No: 1415 Loss = {}
# Batch No: 1416 Loss = {}
# Batch No: 1417 Loss = {}
# Batch No: 1418 Loss = {}
# Batch No: 1419 Loss = {}
# Batch No: 1420 Loss = {}
# Batch No: 1421 Loss = {}
# Batch No: 1422 Loss = {}
# Batch No: 1423 Loss = {}
# Batch No: 1424 Loss = {}
# Batch No: 1425 Loss = {}
# Batch No: 1426 Loss = {}
# Batch No: 1427 Loss = {}
# Batch No: 1428 Loss = {}
# Batch No: 1429 Loss = {}
# Batch No: 1430 Loss = {}
# Batch No: 1431 Loss = {}
# Batch No: 1432 Loss = {}
# Batch No: 1433 Loss = {}
# Batch No: 1434 Loss = {}
# Batch No: 1435 Loss = {}
# Batch No: 1436 Loss = {}
# Batch No: 1437 Loss = {}
# Batch No: 1438 Loss = {}
# Batch No: 1439 Loss = {}
# Batch No: 1440 Loss = {}
# Batch No: 1441 Loss = {}
# Batch No: 1442 Loss = {}
# Batch No: 1443 Loss = {}
# Batch No: 1444 Loss = {}
# Batch No: 1445 Loss = {}
# Batch No: 1446 Loss = {}
# Batch No: 1447 Loss = {}
# Batch No: 1448 Loss = {}
# Batch No: 1449 Loss = {}
# Batch No: 1450 Loss = {}
# Batch No: 1451 Loss = {}
# Batch No: 1452 Loss = {}
# Batch No: 1453 Loss = {}
# Batch No: 1454 Loss = {}
# Batch No: 1455 Loss = {}
# Batch No: 1456 Loss = {}
# Batch No: 1457 Loss = {}
# Batch No: 1458 Loss = {}
# Batch No: 1459 Loss = {}
# Batch No: 1460 Loss = {}
# Batch No: 1461 Loss = {}
# Batch No: 1462 Loss = {}
# Batch No: 1463 Loss = {}
# Batch No: 1464 Loss = {}
# Batch No: 1465 Loss = {}
# Batch No: 1466 Loss = {}
# Batch No: 1467 Loss = {}
# Batch No: 1468 Loss = {}
# Batch No: 1469 Loss = {}
# Batch No: 1470 Loss = {}
# Batch No: 1471 Loss = {}
# Batch No: 1472 Loss = {}
# Batch No: 1473 Loss = {}
# Batch No: 1474 Loss = {}
# Batch No: 1475 Loss = {}
# Batch No: 1476 Loss = {}
# Batch No: 1477 Loss = {}
# Batch No: 1478 Loss = {}
# Batch No: 1479 Loss = {}
# Batch No: 1480 Loss = {}
# Batch No: 1481 Loss = {}
# Batch No: 1482 Loss = {}
# Batch No: 1483 Loss = {}
# Batch No: 1484 Loss = {}
# Batch No: 1485 Loss = {}
# Batch No: 1486 Loss = {}
# Batch No: 1487 Loss = {}
# Batch No: 1488 Loss = {}
# Batch No: 1489 Loss = {}
# Batch No: 1490 Loss = {}
# Batch No: 1491 Loss = {}
# Batch No: 1492 Loss = {}
# Batch No: 1493 Loss = {}
# Batch No: 1494 Loss = {}
# Batch No: 1495 Loss = {}
# Batch No: 1496 Loss = {}
# Batch No: 1497 Loss = {}
# Batch No: 1498 Loss = {}
# Batch No: 1499 Loss = {}
# Batch No: 1500 Loss = {}
# Batch No: 1501 Loss = {}
# Batch No: 1502 Loss = {}
# Batch No: 1503 Loss = {}
# Batch No: 1504 Loss = {}
# Batch No: 1505 Loss = {}
# Batch No: 1506 Loss = {}
# Batch No: 1507 Loss = {}
# Batch No: 1508 Loss = {}
# Batch No: 1509 Loss = {}
# Batch No: 1510 Loss = {}
# Batch No: 1511 Loss = {}
# Batch No: 1512 Loss = {}
# Batch No: 1513 Loss = {}
# Batch No: 1514 Loss = {}
# Batch No: 1515 Loss = {}
# Batch No: 1516 Loss = {}
# Batch No: 1517 Loss = {}
# Batch No: 1518 Loss = {}
# Batch No: 1519 Loss = {}
# Batch No: 1520 Loss = {}
# Batch No: 1521 Loss = {}
# Batch No: 1522 Loss = {}
# Batch No: 1523 Loss = {}
# Batch No: 1524 Loss = {}
# Batch No: 1525 Loss = {}
# Batch No: 1526 Loss = {}
# Batch No: 1527 Loss = {}
# Batch No: 1528 Loss = {}
# Batch No: 1529 Loss = {}
# Batch No: 1530 Loss = {}
# Batch No: 1531 Loss = {}
# Batch No: 1532 Loss = {}
# Batch No: 1533 Loss = {}
# Batch No: 1534 Loss = {}
# Batch No: 1535 Loss = {}
# Batch No: 1536 Loss = {}
# Batch No: 1537 Loss = {}
# Batch No: 1538 Loss = {}
# Batch No: 1539 Loss = {}
# Batch No: 1540 Loss = {}
# Batch No: 1541 Loss = {}
# Batch No: 1542 Loss = {}
# Batch No: 1543 Loss = {}
# Batch No: 1544 Loss = {}
# Batch No: 1545 Loss = {}
# Batch No: 1546 Loss = {}
# Batch No: 1547 Loss = {}
# Batch No: 1548 Loss = {}
# Batch No: 1549 Loss = {}
# Batch No: 1550 Loss = {}
# Batch No: 1551 Loss = {}
# Batch No: 1552 Loss = {}
# Batch No: 1553 Loss = {}
# Batch No: 1554 Loss = {}
# Batch No: 1555 Loss = {}
# Batch No: 1556 Loss = {}
# Batch No: 1557 Loss = {}
# Batch No: 1558 Loss = {}
# Batch No: 1559 Loss = {}
# Batch No: 1560 Loss = {}
# Batch No: 1561 Loss = {}
# Batch No: 1562 Loss = {}
# Batch No: 1563 Loss = {}
# Batch No: 1564 Loss = {}
# Batch No: 1565 Loss = {}
# Batch No: 1566 Loss = {}
# Batch No: 1567 Loss = {}
# Batch No: 1568 Loss = {}
# Batch No: 1569 Loss = {}
# Batch No: 1570 Loss = {}
# Batch No: 1571 Loss = {}
# Batch No: 1572 Loss = {}
# Batch No: 1573 Loss = {}
# Batch No: 1574 Loss = {}
# Batch No: 1575 Loss = {}
# Batch No: 1576 Loss = {}
# Batch No: 1577 Loss = {}
# Batch No: 1578 Loss = {}
# Batch No: 1579 Loss = {}
# Batch No: 1580 Loss = {}
# Batch No: 1581 Loss = {}
# Batch No: 1582 Loss = {}
# Batch No: 1583 Loss = {}
# Batch No: 1584 Loss = {}
# Batch No: 1585 Loss = {}
# Batch No: 1586 Loss = {}
# Batch No: 1587 Loss = {}
# Batch No: 1588 Loss = {}
# Batch No: 1589 Loss = {}
# Batch No: 1590 Loss = {}
# Batch No: 1591 Loss = {}
# Batch No: 1592 Loss = {}
# Batch No: 1593 Loss = {}
# Batch No: 1594 Loss = {}
# Batch No: 1595 Loss = {}
# Batch No: 1596 Loss = {}
# Batch No: 1597 Loss = {}
# Batch No: 1598 Loss = {}
# Batch No: 1599 Loss = {}
# Batch No: 1600 Loss = {}
# Batch No: 1601 Loss = {}
# Batch No: 1602 Loss = {}
# Batch No: 1603 Loss = {}
# Batch No: 1604 Loss = {}
# Batch No: 1605 Loss = {}
# Batch No: 1606 Loss = {}
# Batch No: 1607 Loss = {}
# Batch No: 1608 Loss = {}
# Batch No: 1609 Loss = {}
# Batch No: 1610 Loss = {}
# Batch No: 1611 Loss = {}
# Batch No: 1612 Loss = {}
# Batch No: 1613 Loss = {}
# Batch No: 1614 Loss = {}
# Batch No: 1615 Loss = {}
# Batch No: 1616 Loss = {}
# Batch No: 1617 Loss = {}
# Batch No: 1618 Loss = {}
# Batch No: 1619 Loss = {}
# Batch No: 1620 Loss = {}
# Batch No: 1621 Loss = {}
# Batch No: 1622 Loss = {}
# Batch No: 1623 Loss = {}
# Batch No: 1624 Loss = {}
# Batch No: 1625 Loss = {}
# Batch No: 1626 Loss = {}
# Batch No: 1627 Loss = {}
# Batch No: 1628 Loss = {}
# Batch No: 1629 Loss = {}
# Batch No: 1630 Loss = {}
# Batch No: 1631 Loss = {}
# Batch No: 1632 Loss = {}
# Batch No: 1633 Loss = {}
# Batch No: 1634 Loss = {}
# Batch No: 1635 Loss = {}
# Batch No: 1636 Loss = {}
# Batch No: 1637 Loss = {}
# Batch No: 1638 Loss = {}
# Batch No: 1639 Loss = {}
# Batch No: 1640 Loss = {}
# Batch No: 1641 Loss = {}
# Batch No: 1642 Loss = {}
# Batch No: 1643 Loss = {}
# Batch No: 1644 Loss = {}
# Batch No: 1645 Loss = {}
# Batch No: 1646 Loss = {}
# Batch No: 1647 Loss = {}
# Batch No: 1648 Loss = {}
# Batch No: 1649 Loss = {}
# Batch No: 1650 Loss = {}
# Batch No: 1651 Loss = {}
# Batch No: 1652 Loss = {}
# Batch No: 1653 Loss = {}
# Batch No: 1654 Loss = {}
# Batch No: 1655 Loss = {}
# Batch No: 1656 Loss = {}
# Batch No: 1657 Loss = {}
# Batch No: 1658 Loss = {}
# Batch No: 1659 Loss = {}
# Batch No: 1660 Loss = {}
# Batch No: 1661 Loss = {}
# Batch No: 1662 Loss = {}
# Batch No: 1663 Loss = {}
# Batch No: 1664 Loss = {}
# Batch No: 1665 Loss = {}
# Batch No: 1666 Loss = {}
# Batch No: 1667 Loss = {}
# Batch No: 1668 Loss = {}
# Batch No: 1669 Loss = {}
# Batch No: 1670 Loss = {}
# Batch No: 1671 Loss = {}
# Batch No: 1672 Loss = {}
# Batch No: 1673 Loss = {}
# Batch No: 1674 Loss = {}
# Batch No: 1675 Loss = {}
# Batch No: 1676 Loss = {}
# Batch No: 1677 Loss = {}
# Batch No: 1678 Loss = {}
# Batch No: 1679 Loss = {}
# Batch No: 1680 Loss = {}
# Batch No: 1681 Loss = {}
# Batch No: 1682 Loss = {}
# Batch No: 1683 Loss = {}
# Batch No: 1684 Loss = {}
# Batch No: 1685 Loss = {}
# Batch No: 1686 Loss = {}
# Batch No: 1687 Loss = {}
# Batch No: 1688 Loss = {}
# Batch No: 1689 Loss = {}
# Batch No: 1690 Loss = {}
# Batch No: 1691 Loss = {}
# Batch No: 1692 Loss = {}
# Batch No: 1693 Loss = {}
# Batch No: 1694 Loss = {}
# Batch No: 1695 Loss = {}
# Batch No: 1696 Loss = {}
# Batch No: 1697 Loss = {}
# Batch No: 1698 Loss = {}
# Batch No: 1699 Loss = {}
# Batch No: 1700 Loss = {}
# Batch No: 1701 Loss = {}
# Batch No: 1702 Loss = {}
# Batch No: 1703 Loss = {}
# Batch No: 1704 Loss = {}
# Batch No: 1705 Loss = {}
# Batch No: 1706 Loss = {}
# Batch No: 1707 Loss = {}
# Batch No: 1708 Loss = {}
# Batch No: 1709 Loss = {}
# Batch No: 1710 Loss = {}
# Batch No: 1711 Loss = {}
# Batch No: 1712 Loss = {}
# Batch No: 1713 Loss = {}
# Batch No: 1714 Loss = {}
# Batch No: 1715 Loss = {}
# Batch No: 1716 Loss = {}
# Batch No: 1717 Loss = {}
# Batch No: 1718 Loss = {}
# Batch No: 1719 Loss = {}
# Batch No: 1720 Loss = {}
# Batch No: 1721 Loss = {}
# Batch No: 1722 Loss = {}
# Batch No: 1723 Loss = {}
# Batch No: 1724 Loss = {}
# Batch No: 1725 Loss = {}
# Batch No: 1726 Loss = {}
# Batch No: 1727 Loss = {}
# Batch No: 1728 Loss = {}
# Batch No: 1729 Loss = {}
# Batch No: 1730 Loss = {}
# Batch No: 1731 Loss = {}
# Batch No: 1732 Loss = {}
# Batch No: 1733 Loss = {}
# Batch No: 1734 Loss = {}
# Batch No: 1735 Loss = {}
# Batch No: 1736 Loss = {}
# Batch No: 1737 Loss = {}
# Batch No: 1738 Loss = {}
# Batch No: 1739 Loss = {}
# Batch No: 1740 Loss = {}
# Batch No: 1741 Loss = {}
# Batch No: 1742 Loss = {}
# Batch No: 1743 Loss = {}
# Batch No: 1744 Loss = {}
# Batch No: 1745 Loss = {}
# Batch No: 1746 Loss = {}
# Batch No: 1747 Loss = {}
# Batch No: 1748 Loss = {}
# Batch No: 1749 Loss = {}
# Batch No: 1750 Loss = {}
# Batch No: 1751 Loss = {}
# Batch No: 1752 Loss = {}
# Batch No: 1753 Loss = {}
# Batch No: 1754 Loss = {}
# Batch No: 1755 Loss = {}
# Batch No: 1756 Loss = {}
# Batch No: 1757 Loss = {}
# Batch No: 1758 Loss = {}
# Batch No: 1759 Loss = {}
# Batch No: 1760 Loss = {}
# Batch No: 1761 Loss = {}
# Batch No: 1762 Loss = {}
# Batch No: 1763 Loss = {}
# Batch No: 1764 Loss = {}
# Batch No: 1765 Loss = {}
# Batch No: 1766 Loss = {}
# Batch No: 1767 Loss = {}
# Batch No: 1768 Loss = {}
# Batch No: 1769 Loss = {}
# Batch No: 1770 Loss = {}
# Batch No: 1771 Loss = {}
# Batch No: 1772 Loss = {}
# Batch No: 1773 Loss = {}
# Batch No: 1774 Loss = {}
# Batch No: 1775 Loss = {}
# Batch No: 1776 Loss = {}
# Batch No: 1777 Loss = {}
# Batch No: 1778 Loss = {}
# Batch No: 1779 Loss = {}
# Batch No: 1780 Loss = {}
# Batch No: 1781 Loss = {}
# Batch No: 1782 Loss = {}
# Batch No: 1783 Loss = {}
# Batch No: 1784 Loss = {}
# Batch No: 1785 Loss = {}
# Batch No: 1786 Loss = {}
# Batch No: 1787 Loss = {}
# Batch No: 1788 Loss = {}
# Batch No: 1789 Loss = {}
# Batch No: 1790 Loss = {}
# Batch No: 1791 Loss = {}
# Batch No: 1792 Loss = {}
# Batch No: 1793 Loss = {}
# Batch No: 1794 Loss = {}
# Batch No: 1795 Loss = {}
# Batch No: 1796 Loss = {}
# Batch No: 1797 Loss = {}
# Batch No: 1798 Loss = {}
# Batch No: 1799 Loss = {}
# Batch No: 1800 Loss = {}
# Batch No: 1801 Loss = {}
# Batch No: 1802 Loss = {}
# Batch No: 1803 Loss = {}
# Batch No: 1804 Loss = {}
# Batch No: 1805 Loss = {}
# Batch No: 1806 Loss = {}
# Batch No: 1807 Loss = {}
# Batch No: 1808 Loss = {}
# Batch No: 1809 Loss = {}
# Batch No: 1810 Loss = {}
# Batch No: 1811 Loss = {}
# Batch No: 1812 Loss = {}
# Batch No: 1813 Loss = {}
# Batch No: 1814 Loss = {}
# Batch No: 1815 Loss = {}
# Batch No: 1816 Loss = {}
# Batch No: 1817 Loss = {}
# Batch No: 1818 Loss = {}
# Batch No: 1819 Loss = {}
# Batch No: 1820 Loss = {}
# Batch No: 1821 Loss = {}
# Batch No: 1822 Loss = {}
# Batch No: 1823 Loss = {}
# Batch No: 1824 Loss = {}
# Batch No: 1825 Loss = {}
# Batch No: 1826 Loss = {}
# Batch No: 1827 Loss = {}
# Batch No: 1828 Loss = {}
# Batch No: 1829 Loss = {}
# Batch No: 1830 Loss = {}
# Batch No: 1831 Loss = {}
# Batch No: 1832 Loss = {}
# Batch No: 1833 Loss = {}
# Batch No: 1834 Loss = {}
# Batch No: 1835 Loss = {}
# Batch No: 1836 Loss = {}
# Batch No: 1837 Loss = {}
# Batch No: 1838 Loss = {}
# Batch No: 1839 Loss = {}
# Batch No: 1840 Loss = {}
# Batch No: 1841 Loss = {}
# Batch No: 1842 Loss = {}
# Batch No: 1843 Loss = {}
# Batch No: 1844 Loss = {}
# Batch No: 1845 Loss = {}
# Batch No: 1846 Loss = {}
# Batch No: 1847 Loss = {}
# Batch No: 1848 Loss = {}
# Batch No: 1849 Loss = {}
# Batch No: 1850 Loss = {}
# Batch No: 1851 Loss = {}
# Batch No: 1852 Loss = {}
# Batch No: 1853 Loss = {}
# Batch No: 1854 Loss = {}
# Batch No: 1855 Loss = {}
# Batch No: 1856 Loss = {}
# Batch No: 1857 Loss = {}
# Batch No: 1858 Loss = {}
# Batch No: 1859 Loss = {}
# Batch No: 1860 Loss = {}
# Batch No: 1861 Loss = {}
# Batch No: 1862 Loss = {}
# Batch No: 1863 Loss = {}
# Batch No: 1864 Loss = {}
# Batch No: 1865 Loss = {}
# Batch No: 1866 Loss = {}
# Batch No: 1867 Loss = {}
# Batch No: 1868 Loss = {}
# Batch No: 1869 Loss = {}
# Batch No: 1870 Loss = {}
# Batch No: 1871 Loss = {}
# Batch No: 1872 Loss = {}
# Batch No: 1873 Loss = {}
# Batch No: 1874 Loss = {}
# Batch No: 1875 Loss = {}
# Batch No: 1876 Loss = {}
# Batch No: 1877 Loss = {}
# Batch No: 1878 Loss = {}
# Batch No: 1879 Loss = {}
# Batch No: 1880 Loss = {}
# Batch No: 1881 Loss = {}
# Batch No: 1882 Loss = {}
# Batch No: 1883 Loss = {}
# Batch No: 1884 Loss = {}
# Batch No: 1885 Loss = {}
# Batch No: 1886 Loss = {}
# Batch No: 1887 Loss = {}
# Batch No: 1888 Loss = {}
# Batch No: 1889 Loss = {}
# Batch No: 1890 Loss = {}
# Batch No: 1891 Loss = {}
# Batch No: 1892 Loss = {}
# Batch No: 1893 Loss = {}
# Batch No: 1894 Loss = {}
# Batch No: 1895 Loss = {}
# Batch No: 1896 Loss = {}
# Batch No: 1897 Loss = {}
# Batch No: 1898 Loss = {}
# Batch No: 1899 Loss = {}
# Batch No: 1900 Loss = {}
# Batch No: 1901 Loss = {}
# Batch No: 1902 Loss = {}
# Batch No: 1903 Loss = {}
# Batch No: 1904 Loss = {}
# Batch No: 1905 Loss = {}
# Batch No: 1906 Loss = {}
# Batch No: 1907 Loss = {}
# Batch No: 1908 Loss = {}
# Batch No: 1909 Loss = {}
# Batch No: 1910 Loss = {}
# Batch No: 1911 Loss = {}
# Batch No: 1912 Loss = {}
# Batch No: 1913 Loss = {}
# Batch No: 1914 Loss = {}
# Batch No: 1915 Loss = {}
# Batch No: 1916 Loss = {}
# Batch No: 1917 Loss = {}
# Batch No: 1918 Loss = {}
# Batch No: 1919 Loss = {}
# Batch No: 1920 Loss = {}
# Batch No: 1921 Loss = {}
# Batch No: 1922 Loss = {}
# Batch No: 1923 Loss = {}
# Batch No: 1924 Loss = {}
# Batch No: 1925 Loss = {}
# Batch No: 1926 Loss = {}
# Batch No: 1927 Loss = {}
# Batch No: 1928 Loss = {}
# Batch No: 1929 Loss = {}
# Batch No: 1930 Loss = {}
# Batch No: 1931 Loss = {}
# Batch No: 1932 Loss = {}
# Batch No: 1933 Loss = {}
# Batch No: 1934 Loss = {}
# Batch No: 1935 Loss = {}
# Batch No: 1936 Loss = {}
# Batch No: 1937 Loss = {}
# Batch No: 1938 Loss = {}
# Batch No: 1939 Loss = {}
# Batch No: 1940 Loss = {}
# Batch No: 1941 Loss = {}
# Batch No: 1942 Loss = {}
# Batch No: 1943 Loss = {}
# Batch No: 1944 Loss = {}
# Batch No: 1945 Loss = {}
# Batch No: 1946 Loss = {}
# Batch No: 1947 Loss = {}
# Batch No: 1948 Loss = {}
# Batch No: 1949 Loss = {}
# Batch No: 1950 Loss = {}
# Batch No: 1951 Loss = {}
# Batch No: 1952 Loss = {}
# Batch No: 1953 Loss = {}
# Batch No: 1954 Loss = {}
# Batch No: 1955 Loss = {}
# Batch No: 1956 Loss = {}
# Batch No: 1957 Loss = {}
# Batch No: 1958 Loss = {}
# Batch No: 1959 Loss = {}
# Batch No: 1960 Loss = {}
# Batch No: 1961 Loss = {}
# Batch No: 1962 Loss = {}
# Batch No: 1963 Loss = {}
# Batch No: 1964 Loss = {}
# Batch No: 1965 Loss = {}
# Batch No: 1966 Loss = {}
# Batch No: 1967 Loss = {}
# Batch No: 1968 Loss = {}
# Batch No: 1969 Loss = {}
# Batch No: 1970 Loss = {}
# Batch No: 1971 Loss = {}
# Batch No: 1972 Loss = {}
# Batch No: 1973 Loss = {}
# Batch No: 1974 Loss = {}
# Batch No: 1975 Loss = {}
# Batch No: 1976 Loss = {}
# Batch No: 1977 Loss = {}
# Batch No: 1978 Loss = {}
# Batch No: 1979 Loss = {}
# Batch No: 1980 Loss = {}
# Batch No: 1981 Loss = {}
# Batch No: 1982 Loss = {}
# Batch No: 1983 Loss = {}
# Batch No: 1984 Loss = {}
# Batch No: 1985 Loss = {}
# Batch No: 1986 Loss = {}
# Batch No: 1987 Loss = {}
# Batch No: 1988 Loss = {}
# Batch No: 1989 Loss = {}
# Batch No: 1990 Loss = {}
# Batch No: 1991 Loss = {}
# Batch No: 1992 Loss = {}
# Batch No: 1993 Loss = {}
# Batch No: 1994 Loss = {}
# Batch No: 1995 Loss = {}
# Batch No: 1996 Loss = {}
# Batch No: 1997 Loss = {}
# Batch No: 1998 Loss = {}
# Batch No: 1999 Loss = {}
# Batch No: 2000 Loss = {}
# Batch No: 2001 Loss = {}
# Batch No: 2002 Loss = {}
# Batch No: 2003 Loss = {}
# Batch No: 2004 Loss = {}
# Batch No: 2005 Loss = {}
# Batch No: 2006 Loss = {}
# Batch No: 2007 Loss = {}
# Batch No: 2008 Loss = {}
# Batch No: 2009 Loss = {}
# Batch No: 2010 Loss = {}
# Batch No: 2011 Loss = {}
# Batch No: 2012 Loss = {}
# Batch No: 2013 Loss = {}
# Batch No: 2014 Loss = {}
# Batch No: 2015 Loss = {}
# Batch No: 2016 Loss = {}
# Batch No: 2017 Loss = {}
# Batch No: 2018 Loss = {}
# Batch No: 2019 Loss = {}
# Batch No: 2020 Loss = {}
# Batch No: 2021 Loss = {}
# Batch No: 2022 Loss = {}
# Batch No: 2023 Loss = {}
# Batch No: 2024 Loss = {}
# Batch No: 2025 Loss = {}
# Batch No: 2026 Loss = {}
# Batch No: 2027 Loss = {}
# Batch No: 2028 Loss = {}
# Batch No: 2029 Loss = {}
# Batch No: 2030 Loss = {}
# Batch No: 2031 Loss = {}
# Batch No: 2032 Loss = {}
# Batch No: 2033 Loss = {}
# Batch No: 2034 Loss = {}
# Batch No: 2035 Loss = {}
# Batch No: 2036 Loss = {}
# Batch No: 2037 Loss = {}
# Batch No: 2038 Loss = {}
# Batch No: 2039 Loss = {}
# Batch No: 2040 Loss = {}
# Batch No: 2041 Loss = {}
# Batch No: 2042 Loss = {}
# Batch No: 2043 Loss = {}
# Batch No: 2044 Loss = {}
# Batch No: 2045 Loss = {}
# Batch No: 2046 Loss = {}
# Batch No: 2047 Loss = {}
# Batch No: 2048 Loss = {}
# Batch No: 2049 Loss = {}
# Batch No: 2050 Loss = {}
# Batch No: 2051 Loss = {}
# Batch No: 2052 Loss = {}
# Batch No: 2053 Loss = {}
# Batch No: 2054 Loss = {}
# Batch No: 2055 Loss = {}
# Batch No: 2056 Loss = {}
# Batch No: 2057 Loss = {}
# Batch No: 2058 Loss = {}
# Batch No: 2059 Loss = {}
# Batch No: 2060 Loss = {}
# Batch No: 2061 Loss = {}
# Batch No: 2062 Loss = {}
# Batch No: 2063 Loss = {}
# Batch No: 2064 Loss = {}
# Batch No: 2065 Loss = {}
# Batch No: 2066 Loss = {}
# Batch No: 2067 Loss = {}
# Batch No: 2068 Loss = {}
# Batch No: 2069 Loss = {}
# Batch No: 2070 Loss = {}
# Batch No: 2071 Loss = {}
# Batch No: 2072 Loss = {}
# Batch No: 2073 Loss = {}
# Batch No: 2074 Loss = {}
# Batch No: 2075 Loss = {}
# Batch No: 2076 Loss = {}
# Batch No: 2077 Loss = {}
# Batch No: 2078 Loss = {}
# Batch No: 2079 Loss = {}
# Batch No: 2080 Loss = {}
# Batch No: 2081 Loss = {}
# Batch No: 2082 Loss = {}
# Batch No: 2083 Loss = {}
# Batch No: 2084 Loss = {}
# Batch No: 2085 Loss = {}
# Batch No: 2086 Loss = {}
# Batch No: 2087 Loss = {}
# Batch No: 2088 Loss = {}
# Batch No: 2089 Loss = {}
# Batch No: 2090 Loss = {}
# Batch No: 2091 Loss = {}
# Batch No: 2092 Loss = {}
# Batch No: 2093 Loss = {}
# Batch No: 2094 Loss = {}
# Batch No: 2095 Loss = {}
# Batch No: 2096 Loss = {}
# Batch No: 2097 Loss = {}
# Batch No: 2098 Loss = {}
# Batch No: 2099 Loss = {}
# Batch No: 2100 Loss = {}
# Batch No: 2101 Loss = {}
# Batch No: 2102 Loss = {}
# Batch No: 2103 Loss = {}
# Batch No: 2104 Loss = {}
# Batch No: 2105 Loss = {}
# Batch No: 2106 Loss = {}
# Batch No: 2107 Loss = {}
# Batch No: 2108 Loss = {}
# Batch No: 2109 Loss = {}
# Batch No: 2110 Loss = {}
# Batch No: 2111 Loss = {}
# Batch No: 2112 Loss = {}
# Batch No: 2113 Loss = {}
# Batch No: 2114 Loss = {}
# Batch No: 2115 Loss = {}
# Batch No: 2116 Loss = {}
# Batch No: 2117 Loss = {}
# Batch No: 2118 Loss = {}
# Batch No: 2119 Loss = {}
# Batch No: 2120 Loss = {}
# Batch No: 2121 Loss = {}
# Batch No: 2122 Loss = {}
# Batch No: 2123 Loss = {}
# Batch No: 2124 Loss = {}
# Batch No: 2125 Loss = {}
# Batch No: 2126 Loss = {}
# Batch No: 2127 Loss = {}
# Batch No: 2128 Loss = {}
# Batch No: 2129 Loss = {}
# Batch No: 2130 Loss = {}
# Batch No: 2131 Loss = {}
# Batch No: 2132 Loss = {}
# Batch No: 2133 Loss = {}
# Batch No: 2134 Loss = {}
# Batch No: 2135 Loss = {}
# Batch No: 2136 Loss = {}
# Batch No: 2137 Loss = {}
# Batch No: 2138 Loss = {}
# Batch No: 2139 Loss = {}
# Batch No: 2140 Loss = {}
# Batch No: 2141 Loss = {}
# Batch No: 2142 Loss = {}
# Batch No: 2143 Loss = {}
# Batch No: 2144 Loss = {}
# Batch No: 2145 Loss = {}
# Batch No: 2146 Loss = {}
# Batch No: 2147 Loss = {}
# Batch No: 2148 Loss = {}
# Batch No: 2149 Loss = {}
# Batch No: 2150 Loss = {}
# Batch No: 2151 Loss = {}
# Batch No: 2152 Loss = {}
# Batch No: 2153 Loss = {}
# Batch No: 2154 Loss = {}
# Batch No: 2155 Loss = {}
# Batch No: 2156 Loss = {}
# Batch No: 2157 Loss = {}
# Batch No: 2158 Loss = {}
# Batch No: 2159 Loss = {}
# Batch No: 2160 Loss = {}
# Batch No: 2161 Loss = {}
# Batch No: 2162 Loss = {}
# Batch No: 2163 Loss = {}
# Batch No: 2164 Loss = {}
# Batch No: 2165 Loss = {}
# Batch No: 2166 Loss = {}
# Batch No: 2167 Loss = {}
# Batch No: 2168 Loss = {}
# Batch No: 2169 Loss = {}
# Batch No: 2170 Loss = {}
# Batch No: 2171 Loss = {}
# Batch No: 2172 Loss = {}
# Batch No: 2173 Loss = {}
# Batch No: 2174 Loss = {}
# Batch No: 2175 Loss = {}
# Batch No: 2176 Loss = {}
# Batch No: 2177 Loss = {}
# Batch No: 2178 Loss = {}
# Batch No: 2179 Loss = {}
# Batch No: 2180 Loss = {}
# Batch No: 2181 Loss = {}
# Batch No: 2182 Loss = {}
# Batch No: 2183 Loss = {}
# Batch No: 2184 Loss = {}
# Batch No: 2185 Loss = {}
# Batch No: 2186 Loss = {}
# Batch No: 2187 Loss = {}
# Batch No: 2188 Loss = {}
# Batch No: 2189 Loss = {}
# Batch No: 2190 Loss = {}
# Batch No: 2191 Loss = {}
# Batch No: 2192 Loss = {}
# Batch No: 2193 Loss = {}
# Batch No: 2194 Loss = {}
# Batch No: 2195 Loss = {}
# Batch No: 2196 Loss = {}
# Batch No: 2197 Loss = {}
# Batch No: 2198 Loss = {}
# Batch No: 2199 Loss = {}
# Batch No: 2200 Loss = {}
# Batch No: 2201 Loss = {}
# Batch No: 2202 Loss = {}
# Batch No: 2203 Loss = {}
# Batch No: 2204 Loss = {}
# Batch No: 2205 Loss = {}
# Batch No: 2206 Loss = {}
# Batch No: 2207 Loss = {}
# Batch No: 2208 Loss = {}
# Batch No: 2209 Loss = {}
# Batch No: 2210 Loss = {}
# Batch No: 2211 Loss = {}
# Batch No: 2212 Loss = {}
# Batch No: 2213 Loss = {}
# Batch No: 2214 Loss = {}
# Batch No: 2215 Loss = {}
# Batch No: 2216 Loss = {}
# Batch No: 2217 Loss = {}
# Batch No: 2218 Loss = {}
# Batch No: 2219 Loss = {}
# Batch No: 2220 Loss = {}
# Batch No: 2221 Loss = {}
# Batch No: 2222 Loss = {}
# Batch No: 2223 Loss = {}
# Batch No: 2224 Loss = {}
# Batch No: 2225 Loss = {}
# Batch No: 2226 Loss = {}
# Batch No: 2227 Loss = {}
# Batch No: 2228 Loss = {}
# Batch No: 2229 Loss = {}
# Batch No: 2230 Loss = {}
# Batch No: 2231 Loss = {}
# Batch No: 2232 Loss = {}
# Batch No: 2233 Loss = {}
# Batch No: 2234 Loss = {}
# Batch No: 2235 Loss = {}
# Batch No: 2236 Loss = {}
# Batch No: 2237 Loss = {}
# Batch No: 2238 Loss = {}
# Batch No: 2239 Loss = {}
# Batch No: 2240 Loss = {}
# Batch No: 2241 Loss = {}
# Batch No: 2242 Loss = {}
# Batch No: 2243 Loss = {}
# Batch No: 2244 Loss = {}
# Batch No: 2245 Loss = {}
# Batch No: 2246 Loss = {}
# Batch No: 2247 Loss = {}
# Batch No: 2248 Loss = {}
# Batch No: 2249 Loss = {}
# Batch No: 2250 Loss = {}
# Batch No: 2251 Loss = {}
# Batch No: 2252 Loss = {}
# Batch No: 2253 Loss = {}
# Batch No: 2254 Loss = {}
# Batch No: 2255 Loss = {}
# Batch No: 2256 Loss = {}
# Batch No: 2257 Loss = {}
# Batch No: 2258 Loss = {}
# Batch No: 2259 Loss = {}
# Batch No: 2260 Loss = {}
# Batch No: 2261 Loss = {}
# Batch No: 2262 Loss = {}
# Batch No: 2263 Loss = {}
# Batch No: 2264 Loss = {}
# Batch No: 2265 Loss = {}
# Batch No: 2266 Loss = {}
# Batch No: 2267 Loss = {}
# Batch No: 2268 Loss = {}
# Batch No: 2269 Loss = {}
# Batch No: 2270 Loss = {}
# Batch No: 2271 Loss = {}
# Batch No: 2272 Loss = {}
# Batch No: 2273 Loss = {}
# Batch No: 2274 Loss = {}
# Batch No: 2275 Loss = {}
# Batch No: 2276 Loss = {}
# Batch No: 2277 Loss = {}
# Batch No: 2278 Loss = {}
# Batch No: 2279 Loss = {}
# Batch No: 2280 Loss = {}
# Batch No: 2281 Loss = {}
# Batch No: 2282 Loss = {}
# Batch No: 2283 Loss = {}
# Batch No: 2284 Loss = {}
# Batch No: 2285 Loss = {}
# Batch No: 2286 Loss = {}
# Batch No: 2287 Loss = {}
# Batch No: 2288 Loss = {}
# Batch No: 2289 Loss = {}
# Batch No: 2290 Loss = {}
# Batch No: 2291 Loss = {}
# Batch No: 2292 Loss = {}
# Batch No: 2293 Loss = {}
# Batch No: 2294 Loss = {}
# Batch No: 2295 Loss = {}
# Batch No: 2296 Loss = {}
# Batch No: 2297 Loss = {}
# Batch No: 2298 Loss = {}
# Batch No: 2299 Loss = {}
# Batch No: 2300 Loss = {}
# Batch No: 2301 Loss = {}
# Batch No: 2302 Loss = {}
# Batch No: 2303 Loss = {}
# Batch No: 2304 Loss = {}
# Batch No: 2305 Loss = {}
# Batch No: 2306 Loss = {}
# Batch No: 2307 Loss = {}
# Batch No: 2308 Loss = {}
# Batch No: 2309 Loss = {}
# Batch No: 2310 Loss = {}
# Batch No: 2311 Loss = {}
# Batch No: 2312 Loss = {}
# Batch No: 2313 Loss = {}
# Batch No: 2314 Loss = {}
# Batch No: 2315 Loss = {}
# Batch No: 2316 Loss = {}
# Batch No: 2317 Loss = {}
# Batch No: 2318 Loss = {}
# Batch No: 2319 Loss = {}
# Batch No: 2320 Loss = {}
# Batch No: 2321 Loss = {}
# Batch No: 2322 Loss = {}
# Batch No: 2323 Loss = {}
# Batch No: 2324 Loss = {}
# Batch No: 2325 Loss = {}
# Batch No: 2326 Loss = {}
# Batch No: 2327 Loss = {}
# Batch No: 2328 Loss = {}
# Batch No: 2329 Loss = {}
# Batch No: 2330 Loss = {}
# Batch No: 2331 Loss = {}
# Batch No: 2332 Loss = {}
# Batch No: 2333 Loss = {}
# Batch No: 2334 Loss = {}
# Batch No: 2335 Loss = {}
# Batch No: 2336 Loss = {}
# Batch No: 2337 Loss = {}
# Batch No: 2338 Loss = {}
# Batch No: 2339 Loss = {}
# Batch No: 2340 Loss = {}
# Batch No: 2341 Loss = {}
# Batch No: 2342 Loss = {}
# Batch No: 2343 Loss = {}
# Batch No: 2344 Loss = {}
# Batch No: 2345 Loss = {}
# Batch No: 2346 Loss = {}
# Batch No: 2347 Loss = {}
# Batch No: 2348 Loss = {}
# Batch No: 2349 Loss = {}
# Batch No: 2350 Loss = {}
# Batch No: 2351 Loss = {}
# Batch No: 2352 Loss = {}
# Batch No: 2353 Loss = {}
# Batch No: 2354 Loss = {}
# Batch No: 2355 Loss = {}
# Batch No: 2356 Loss = {}
# Batch No: 2357 Loss = {}
# Batch No: 2358 Loss = {}
# Batch No: 2359 Loss = {}
# Batch No: 2360 Loss = {}
# Batch No: 2361 Loss = {}
# Batch No: 2362 Loss = {}
# Batch No: 2363 Loss = {}
# Batch No: 2364 Loss = {}
# Batch No: 2365 Loss = {}
# Batch No: 2366 Loss = {}
# Batch No: 2367 Loss = {}
# Batch No: 2368 Loss = {}
# Batch No: 2369 Loss = {}
# Batch No: 2370 Loss = {}
# Batch No: 2371 Loss = {}
# Batch No: 2372 Loss = {}
# Batch No: 2373 Loss = {}
# Batch No: 2374 Loss = {}
# Batch No: 2375 Loss = {}
# Batch No: 2376 Loss = {}
# Batch No: 2377 Loss = {}
# Batch No: 2378 Loss = {}
# Batch No: 2379 Loss = {}
# Batch No: 2380 Loss = {}
# Batch No: 2381 Loss = {}
# Batch No: 2382 Loss = {}
# Batch No: 2383 Loss = {}
# Batch No: 2384 Loss = {}
# Batch No: 2385 Loss = {}
# Batch No: 2386 Loss = {}
# Batch No: 2387 Loss = {}
# Batch No: 2388 Loss = {}
# Batch No: 2389 Loss = {}
# Batch No: 2390 Loss = {}
# Batch No: 2391 Loss = {}
# Batch No: 2392 Loss = {}
# Batch No: 2393 Loss = {}
# Batch No: 2394 Loss = {}
# Batch No: 2395 Loss = {}
# Batch No: 2396 Loss = {}
# Batch No: 2397 Loss = {}
# Batch No: 2398 Loss = {}
# Batch No: 2399 Loss = {}
# Batch No: 2400 Loss = {}
# Batch No: 2401 Loss = {}
# Batch No: 2402 Loss = {}
# Batch No: 2403 Loss = {}
# Batch No: 2404 Loss = {}
# Batch No: 2405 Loss = {}
# Batch No: 2406 Loss = {}
# Batch No: 2407 Loss = {}
# Batch No: 2408 Loss = {}
# Batch No: 2409 Loss = {}
# Batch No: 2410 Loss = {}
# Batch No: 2411 Loss = {}
# Batch No: 2412 Loss = {}
# Batch No: 2413 Loss = {}
# Batch No: 2414 Loss = {}
# Batch No: 2415 Loss = {}
# Batch No: 2416 Loss = {}
# Batch No: 2417 Loss = {}
# Batch No: 2418 Loss = {}
# Batch No: 2419 Loss = {}
# Batch No: 2420 Loss = {}
# Batch No: 2421 Loss = {}
# Batch No: 2422 Loss = {}
# Batch No: 2423 Loss = {}
# Batch No: 2424 Loss = {}
# Batch No: 2425 Loss = {}
# Batch No: 2426 Loss = {}
# Batch No: 2427 Loss = {}
# Batch No: 2428 Loss = {}
# Batch No: 2429 Loss = {}
# Batch No: 2430 Loss = {}
# Batch No: 2431 Loss = {}
# Batch No: 2432 Loss = {}
# Batch No: 2433 Loss = {}
# Batch No: 2434 Loss = {}
# Batch No: 2435 Loss = {}
# Batch No: 2436 Loss = {}
# Batch No: 2437 Loss = {}
# Batch No: 2438 Loss = {}
# Batch No: 2439 Loss = {}
# Batch No: 2440 Loss = {}
# Batch No: 2441 Loss = {}
# Batch No: 2442 Loss = {}
# Batch No: 2443 Loss = {}
# Batch No: 2444 Loss = {}
# Batch No: 2445 Loss = {}
# Batch No: 2446 Loss = {}
# Batch No: 2447 Loss = {}
# Batch No: 2448 Loss = {}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/0h/96f5xt0s59j0cyt_3yf1j_0w0000gn/T/ipykernel_23349/4095803453.py in <module>
#      10             example = []
#      11             for i in range(len(text)):
# ---> 12                 doc = nlp.make_doc(text[i])
#      13                 example.append(Example.from_dict(doc, annotations[i]))
#      14             nlp.update(example, sgd=optimizer, drop=0.2, losses = losses)
#
# ~/anaconda3/lib/python3.7/site-packages/spacy/language.py in make_doc(self, text)
#    1089                 Errors.E088.format(length=len(text), max_length=self.max_length)
#    1090             )
# -> 1091         return self.tokenizer(text)
#    1092
#    1093     def _ensure_doc(self, doc_like: Union[str, Doc, bytes]) -> Doc:
#
# ~/anaconda3/lib/python3.7/site-packages/spacy/tokenizer.pyx in spacy.tokenizer.Tokenizer.__call__()
#
# ~/anaconda3/lib/python3.7/site-packages/spacy/tokenizer.pyx in spacy.tokenizer.Tokenizer._tokenize_affixes()
#
# ~/anaconda3/lib/python3.7/site-packages/spacy/tokenizer.pyx in spacy.tokenizer.Tokenizer._tokenize()
#
# ~/anaconda3/lib/python3.7/site-packages/spacy/tokenizer.pyx in spacy.tokenizer.Tokenizer._attach_tokens()
#
# ~/anaconda3/lib/python3.7/site-packages/spacy/vocab.pyx in spacy.vocab.Vocab.get()
#
# ~/anaconda3/lib/python3.7/site-packages/spacy/vocab.pyx in spacy.vocab.Vocab._new_lexeme()
#
# ~/anaconda3/lib/python3.7/site-packages/spacy/lang/lex_attrs.py in lower(string)
#     143
#     144
# --> 145 def lower(string: str) -> str:
#     146     return string.lower()
#     147
#
# KeyboardInterrupt:
